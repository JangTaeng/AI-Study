# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 02. 파이썬 변수

# %% [markdown]
# ### 011 변수 사용하기

# %% [markdown]
# 삼성전자라는 변수로 50,000원을 바인딩해보세요. 삼성전자 주식 10주를 보유하고 있을 때 총 평가금액을 출력하세요.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 변수(variable)는 값을 저장하는 이름표입니다. <code>=</code> 기호를 사용해 값을 바인딩(저장)합니다.</br>
# <pre>
# 삼성전자 = 50000
# 총평가금액 = 삼성전자 * 10
# print(총평가금액)
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ### 012 변수 사용하기

# %% [markdown]
# 다음 표는 삼성전자의 일부 투자정보입니다. 변수를 사용해서 시가총액, 현재가, PER 등을 바인딩해보세요.
#
# | 항목 | 값 |
# | --- | --- |
# | 시가총액 | 298조 |
# | 현재가 | 50,000원 |
# | PER | 15.79 |

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 정수는 int, 실수는 float 타입입니다. type() 함수로 타입을 확인할 수 있습니다.</br>
# <pre>
# 시가총액 = 298000000000000
# 현재가 = 50000
# PER = 15.79
# print(시가총액, type(시가총액))
# print(현재가, type(현재가))
# print(PER, type(PER))
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ### 013 문자열 출력

# %% [markdown]
# 변수 s와 t에는 각각 문자열이 바인딩 되어있습니다.
# ```
# s = "hello"
# t = "python"
# ```
# 두 변수를 이용하여 아래와 같이 출력해보세요.
# ```
# 실행 예:
# hello! python
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 문자열끼리 <code>+</code>로 이어붙일 수 있습니다. print() 안에 쉼표(,)로 구분하면 공백을 넣어 출력합니다.</br>
# <pre>
# s = "hello"
# t = "python"
# print(s+"!", t)
# </pre>
# </details>

# %%
s = "hello"
t = "python"
# 여기에 코드를 작성하세요

# %% [markdown]
# ### 014 파이썬을 이용한 값 계산

# %% [markdown]
# 아래 코드의 실행 결과를 예상해보세요.
# ```
# 2 + 2 * 3
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 파이썬도 수학과 동일하게 곱셈(*)이 덧셈(+)보다 먼저 계산됩니다. (연산자 우선순위)</br>
# 2 + (2 * 3) = 2 + 6 = 8
# <pre>
# print(2 + 2 * 3)  # 결과: 8
# </pre>
# </details>

# %%
# 직접 실행해서 결과를 확인해보세요
print(2 + 2 * 3)

# %% [markdown]
# ### 015 type 함수

# %% [markdown]
# type() 함수는 데이터 타입을 판별합니다. 변수 a에는 128 숫자가 바인딩돼 있어 type 함수가 int(정수)형임을 알려줍니다.
# ```
# a = 128
# print(type(a))
# # 출력: <class 'int'>
# ```
# 아래 변수에 바인딩된 값의 타입을 판별해보세요.
# ```
# a = "132"
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 따옴표로 감싸면 문자열(str) 타입이 됩니다. 숫자처럼 보여도 따옴표가 있으면 문자열입니다.</br>
# <pre>
# a = "132"
# print(type(a))  # &lt;class 'str'&gt;
# </pre>
# </details>

# %%
a = "132"
# 여기에 코드를 작성하세요

# %% [markdown]
# ### 016 문자열을 정수로 변환

# %% [markdown]
# 문자열 '720'를 정수형으로 변환해보세요.
# ```
# num_str = "720"
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# int() 함수를 사용하면 문자열을 정수로 변환할 수 있습니다.</br>
# <pre>
# num_str = "720"
# num_int = int(num_str)
# print(num_int+1, type(num_int))
# </pre>
# </details>

# %%
num_str = "720"
# 여기에 코드를 작성하세요

# %% [markdown]
# ### 017 정수를 문자열로 변환

# %% [markdown]
# 정수 100을 문자열 '100'으로 변환해보세요.
# ```
# num = 100
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# str() 함수를 사용하면 정수를 문자열로 변환할 수 있습니다.</br>
# <pre>
# num = 100
# result = str(num)
# print(result, type(result))
# </pre>
# </details>

# %%
num = 100
# 여기에 코드를 작성하세요

# %% [markdown]
# ### 018 문자열을 실수로 변환

# %% [markdown]
# 문자열 "15.79"를 실수(float) 타입으로 변환해보세요.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# float() 함수를 사용하면 문자열을 실수(소수점이 있는 숫자)로 변환할 수 있습니다.</br>
# <pre>
# data = "15.79"
# data = float(data)
# print(data, type(data))
# </pre>
# </details>

# %%
data = "15.79"
# 여기에 코드를 작성하세요

# %% [markdown]
# ### 019 문자열을 정수로 변환

# %% [markdown]
# year라는 변수가 문자열 타입의 연도를 바인딩하고 있습니다. 이를 정수로 변환한 후 최근 3년의 연도를 화면에 출력해보세요.
# ```
# year = "2020"
# ```
# ```
# 실행 예:
# 2017
# 2018
# 2019
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 문자열을 int()로 변환한 뒤 빼기 연산을 할 수 있습니다.</br>
# <pre>
# year = "2020"
# print(int(year)-3)  # 2017
# print(int(year)-2)  # 2018
# print(int(year)-1)  # 2019
# </pre>
# </details>

# %%
year = "2020"
# 여기에 코드를 작성하세요

# %% [markdown]
# ### 020 파이썬 계산

# %% [markdown]
# 에이컨이 월 48,584원에 무이자 36개월의 조건으로 홈쇼핑에서 판매되고 있습니다. 총 금액을 계산한 후 이를 화면에 출력해보세요. (변수 사용하기)

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 변수를 사용하면 코드가 더 읽기 쉬워지고 나중에 값을 바꾸기도 편합니다.</br>
# <pre>
# 월 = 48584
# 총금액 = 월 * 36
# print(총금액)
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
