# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 08. 파이썬 반복문 (141 ~ 150)

# %% [markdown]
# ### 141 for문 + 연산

# %% [markdown]
# 다음과 같이 판매가가 저장된 리스트가 있을 때 부가세(10원)가 포함된 가격을 for문을 사용해서 출력하라.
# ```python
# 리스트 = [100, 200, 300]
# ```
# ```
# 실행 예:
# 110
# 210
# 310
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 들여쓰기된 코드에서 변수에 10을 더해 출력합니다.</br>
# <pre>
# 리스트 = [100, 200, 300]
# for 변수 in 리스트:
#     print(변수 + 10)
# </pre>
# </details>

# %%
리스트 = [100, 200, 300]
# 여기에 코드를 작성하세요
for i in 리스트:
    print(i+10)
# Out:
# 110
# 210
# 310

# %% [markdown]
# ### 142 for문 + 문자열 출력

# %% [markdown]
# for문을 사용해서 리스트에 저장된 값을 다음과 같이 출력하라.
# ```python
# 리스트 = ["김밥", "라면", "튀김"]
# ```
# ```
# 실행 예:
# 오늘의 메뉴: 김밥
# 오늘의 메뉴: 라면
# 오늘의 메뉴: 튀김
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# 리스트 = ["김밥", "라면", "튀김"]
# for 메뉴 in 리스트:
#     print("오늘의 메뉴: " + 메뉴)
#
# # 또는:
# for 메뉴 in 리스트:
#     print("오늘의 메뉴:", 메뉴)
# </pre>
# </details>

# %%
리스트 = ["김밥", "라면", "튀김"]
# 여기에 코드를 작성하세요
for i in 리스트:
    print("오늘의 메뉴:",i)
# Out:
# 오늘의 메뉴: 김밥
# 오늘의 메뉴: 라면
# 오늘의 메뉴: 튀김

# %% [markdown]
# ### 143 for문 + len()

# %% [markdown]
# 리스트에 주식 종목이름이 저장돼 있다. 저장된 문자열의 길이를 출력하라.
# ```python
# 리스트 = ["SK하이닉스", "삼성전자", "LG전자"]
# ```
# ```
# 실행 예:
# 6
# 4
# 4
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# len() 함수로 문자열 길이를 구합니다.</br>
# <pre>
# 리스트 = ["SK하이닉스", "삼성전자", "LG전자"]
# for 종목명 in 리스트:
#     print(len(종목명))
# </pre>
# </details>

# %%
리스트 = ["SK하이닉스", "삼성전자", "LG전자"]
# 여기에 코드를 작성하세요
for i in 리스트:
    print(len(i))
# Out:
# 6
# 4
# 4

# %% [markdown]
# ### 144 for문 + len() (2)

# %% [markdown]
# 리스트에는 동물이름이 저장돼 있다. 동물 이름과 글자수를 출력하라.
# ```python
# 리스트 = ['dog', 'cat', 'parrot']
# ```
# ```
# 실행 예:
# dog 3
# cat 3
# parrot 6
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# 리스트 = ['dog', 'cat', 'parrot']
# for 이름 in 리스트:
#     print(이름, len(이름))
# </pre>
# </details>

# %%
리스트 = ['dog', 'cat', 'parrot']
# 여기에 코드를 작성하세요
for i in 리스트:
    print(i,len(i))
# Out:
# dog 3
# cat 3
# parrot 6

# %% [markdown]
# ### 145 for문 + 인덱싱

# %% [markdown]
# for문을 사용해서 동물 이름의 첫 글자만 출력하라.
# ```python
# 리스트 = ['dog', 'cat', 'parrot']
# ```
# ```
# 실행 예:
# d
# c
# p
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 인덱스 0으로 첫 글자를 가져옵니다.</br>
# <pre>
# 리스트 = ['dog', 'cat', 'parrot']
# for 이름 in 리스트:
#     print(이름[0])
# </pre>
# </details>

# %%
리스트 = ['dog', 'cat', 'parrot']
# 여기에 코드를 작성하세요
for i in 리스트:
    print(i[0])
# Out:
# d
# c
# p

# %% [markdown]
# ### 146 for문 + 문자열 연산

# %% [markdown]
# for문을 사용해서 다음과 같이 출력하라.
# ```python
# 리스트 = [1, 2, 3]
# ```
# ```
# 실행 예:
# 3 x 1
# 3 x 2
# 3 x 3
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 숫자를 str()로 변환하거나 print()의 여러 인자를 활용합니다.</br>
# <pre>
# 리스트 = [1, 2, 3]
# for 변수 in 리스트:
#     print("3 x " + str(변수))
#
# # 또는:
# for 변수 in 리스트:
#     print("3 x", 변수)
# </pre>
# </details>

# %%
리스트 = [1, 2, 3]
# 여기에 코드를 작성하세요
for i in 리스트:
    print("3 x",i)
# Out:
# 3 x 1
# 3 x 2
# 3 x 3

# %% [markdown]
# ### 147 for문 + 곱셈 출력

# %% [markdown]
# for문을 사용해서 다음과 같이 출력하라.
# ```python
# 리스트 = [1, 2, 3]
# ```
# ```
# 실행 예:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# 리스트 = [1, 2, 3]
# for 변수 in 리스트:
#     print("3 x ", 변수, "=", 3 * 변수)
#
# # format 활용:
# for 변수 in 리스트:
#     print("3 x {} = {}".format(변수, 3 * 변수))
# </pre>
# </details>

# %%
리스트 = [1, 2, 3]
# 여기에 코드를 작성하세요
for i in 리스트:
    print("3 x",i,"=",3*i)
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9

# %% [markdown]
# ### 148 for문 + 슬라이싱 (일부 출력)

# %% [markdown]
# for문을 사용해서 다음과 같이 출력하라.
# ```python
# 리스트 = ["가", "나", "다", "라"]
# ```
# ```
# 실행 예:
# 나
# 다
# 라
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 슬라이싱 [1:]으로 첫 번째 원소를 제외합니다.</br>
# <pre>
# 리스트 = ["가", "나", "다", "라"]
# for 변수 in 리스트[1:]:
#     print(변수)
# </pre>
# </details>

# %%
리스트 = ["가", "나", "다", "라"]
# 여기에 코드를 작성하세요
for i in 리스트[1:]:
    print(i)
# Out:
# 나
# 다
# 라

# %% [markdown]
# ### 149 for문 + 슬라이싱 (홀수 인덱스)

# %% [markdown]
# for문을 사용해서 다음과 같이 출력하라.
# ```python
# 리스트 = ["가", "나", "다", "라"]
# ```
# ```
# 실행 예:
# 가
# 다
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 슬라이싱의 세 번째 인자(증감폭)를 2로 지정합니다.</br>
# <pre>
# 리스트 = ["가", "나", "다", "라"]
# for 변수 in 리스트[::2]:
#     print(변수)
# </pre>
# </details>

# %%
리스트 = ["가", "나", "다", "라"]
# 여기에 코드를 작성하세요
for i in 리스트[::2]:
    print(i)
# Out:
# 가
# 다

# %% [markdown]
# ### 150 for문 + 슬라이싱 (역순 출력)

# %% [markdown]
# for문을 사용해서 다음과 같이 출력하라.
# ```python
# 리스트 = ["가", "나", "다", "라"]
# ```
# ```
# 실행 예:
# 라
# 다
# 나
# 가
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 증감폭을 -1로 지정하면 뒤에서부터 앞 방향으로 순회합니다.</br>
# <pre>
# 리스트 = ["가", "나", "다", "라"]
# for 변수 in 리스트[::-1]:
#     print(변수)
# </pre>
# </details>

# %%
리스트 = ["가", "나", "다", "라"]
# 여기에 코드를 작성하세요
for i in 리스트[::-1]:
    print(i)
# Out:
# 라
# 다
# 나
# 가
