# %% [markdown]
# # 파이썬 심화 문제집 - 딕셔너리

# %% [markdown]
# ## 딕셔너리 심화 (331 ~ 340)

# %% [markdown]
# ### 331 딕셔너리로 행렬 표현

# %% [markdown]
# 2x3 행렬을 딕셔너리로 표현하고 (1,2) 위치의 값을 출력하세요.
# ```
# matrix[(0,0)]=1, (0,1)=2, (0,2)=3
#       (1,0)=4, (1,1)=5, (1,2)=6
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# matrix={(i,j):i*3+j+1 for i in range(2) for j in range(3)}
# print(matrix)
# print(matrix[(1,2)])  # 6
# </pre>
# </details>

# %%
matrix={(i,j):i*3+j+1 for i in range(2) for j in range(3)}
# 여기에 코드를 작성하세요
print(matrix)
print(matrix[(1,2)])  # 6
# Out:
# {(0, 0): 1, (0, 1): 2, (0, 2): 3, (1, 0): 4, (1, 1): 5, (1, 2): 6}
# 6

# %% [markdown]
# ### 332 딕셔너리로 그래프 표현

# %% [markdown]
# 도시 간 연결 그래프를 인접 리스트(딕셔너리)로 표현하세요.
# ```python
# # 서울-부산, 서울-대전, 부산-대구, 대전-대구
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# graph={
#     '서울':['부산','대전'],
#     '부산':['서울','대구'],
#     '대전':['서울','대구'],
#     '대구':['부산','대전']
# }
# for city,neighbors in graph.items():
#     print(f'{city} -> {neighbors}')
# </pre>
# </details>

# %%
graph={
    '서울':['부산','대전'],
    '부산':['서울','대구'],
    '대전':['서울','대구'],
    '대구':['부산','대전']
}
# 여기에 코드를 작성하세요
for city,neighbors in graph.items():
    print(f'{city} -> {neighbors}')
# Out:
# 서울 -> ['부산', '대전']
# 부산 -> ['서울', '대구']
# 대전 -> ['서울', '대구']
# 대구 -> ['부산', '대전']

# %% [markdown]
# ### 333 딕셔너리로 환율 변환기

# %% [markdown]
# 딕셔너리 환율을 활용해 금액을 원화로 변환하는 함수를 만드세요.
# ```python
# rates={'USD':1300,'EUR':1400,'JPY':9.0,'CNY':180}
# # convert(100,'USD') → 130000원
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# rates={'USD':1300,'EUR':1400,'JPY':9.0,'CNY':180}
# def convert(amount,currency):
#     if currency not in rates:
#         return '지원하지 않는 통화'
#     return amount * rates[currency]
# print(convert(100,'USD'))  # 130000
# print(convert(1000,'JPY')) # 9000.0
# </pre>
# </details>

# %%
rates={'USD':1300,'EUR':1400,'JPY':9.0,'CNY':180}
# 여기에 코드를 작성하세요
def convert(amount,currency):
    if currency not in rates:
        return '지원하지 않는 통화'
    return amount * rates[currency]
print(convert(100,'USD'))  # 130000
print(convert(1000,'JPY')) # 9000.0
# Out:
# 130000
# 9000.0

# %% [markdown]
# ### 334 딕셔너리 키 이름 변경

# %% [markdown]
# 아래 딕셔너리의 키 이름을 영어에서 한글로 바꾸세요.
# ```python
# d={'name':'김파이','age':25,'city':'서울'}
# # 결과: {'이름':'김파이','나이':25,'도시':'서울'}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# d={'name':'김파이','age':25,'city':'서울'}
# key_map={'name':'이름','age':'나이','city':'도시'}
# result={key_map[k]:v for k,v in d.items()}
# print(result)
# </pre>
# </details>

# %%
d={'name':'김파이','age':25,'city':'서울'}
# 여기에 코드를 작성하세요
key_map={'name':'이름','age':'나이','city':'도시'}
result={key_map[k]:v for k,v in d.items()}
print(result)
# Out:
# {'이름': '김파이', '나이': 25, '도시': '서울'}

# %% [markdown]
# ### 335 딕셔너리로 성적 등급 처리

# %% [markdown]
# 점수 딕셔너리를 성적 등급 딕셔너리로 변환하세요.
# ```python
# scores={'민수':85,'지영':62,'철수':91,'수연':55,'태호':78}
# # 90이상:A, 80이상:B, 70이상:C, 60이상:D, 60미만:F
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# scores={'민수':85,'지영':62,'철수':91,'수연':55,'태호':78}
# def grade(s):
#     if s>=90: return 'A'
#     elif s>=80: return 'B'
#     elif s>=70: return 'C'
#     elif s>=60: return 'D'
#     else: return 'F'
# grades={name:grade(s) for name,s in scores.items()}
# print(grades)
# </pre>
# </details>

# %%
scores={'민수':85,'지영':62,'철수':91,'수연':55,'태호':78}
# 여기에 코드를 작성하세요
def grade(s):
    if s>=90: return 'A'
    elif s>=80: return 'B'
    elif s>=70: return 'C'
    elif s>=60: return 'D'
    else: return 'F'
grades={name:grade(s) for name,s in scores.items()}
print(grades)
# Out:
# {'민수': 'B', '지영': 'D', '철수': 'A', '수연': 'F', '태호': 'C'}

# %% [markdown]
# ### 336 딕셔너리 항목 수 세기

# %% [markdown]
# 딕셔너리 리스트에서 특정 조건에 맞는 항목 수를 세세요.
# ```python
# people=[{'name':'A','gender':'남'},{'name':'B','gender':'여'},
#         {'name':'C','gender':'남'},{'name':'D','gender':'여'},{'name':'E','gender':'남'}]
# # 남자 수, 여자 수
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# people=[{'name':'A','gender':'남'},{'name':'B','gender':'여'},
#         {'name':'C','gender':'남'},{'name':'D','gender':'여'},{'name':'E','gender':'남'}]
# from collections import Counter
# counts=Counter(p['gender'] for p in people)
# print(counts)
# </pre>
# </details>

# %%
people=[{'name':'A','gender':'남'},{'name':'B','gender':'여'},
        {'name':'C','gender':'남'},{'name':'D','gender':'여'},{'name':'E','gender':'남'}]
# 여기에 코드를 작성하세요
from collections import Counter
counts=Counter(p['gender'] for p in people)
print(counts)
# Out:
# Counter({'남': 3, '여': 2})

# %% [markdown]
# ### 337 딕셔너리로 스택 구현

# %% [markdown]
# 딕셔너리를 사용해 이름이 붙은 스택을 구현하세요. push, pop, peek 기능을 구현하세요.

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# class NamedStack:
#     def __init__(self, name):
#         self.name = name
#         self.data = []
#     def push(self, val): self.data.append(val)
#     def pop(self): return self.data.pop() if self.data else None
#     def peek(self): return self.data[-1] if self.data else None
#
# stacks={'A':NamedStack('A'),'B':NamedStack('B')}
# stacks['A'].push(1); stacks['A'].push(2)
# stacks['B'].push(10)
# print(stacks['A'].pop())  # 2
# print(stacks['B'].peek()) # 10
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
class NamedStack:
    def __init__(self, name):
        self.name = name
        self.data = []
    def push(self, val): self.data.append(val)
    def pop(self): return self.data.pop() if self.data else None
    def peek(self): return self.data[-1] if self.data else None

stacks={'A':NamedStack('A'),'B':NamedStack('B')}
stacks['A'].push(1); stacks['A'].push(2)
stacks['B'].push(10)
print(stacks['A'].pop())  # 2
print(stacks['B'].peek()) # 10
# Out:
# 2
# 10

# %% [markdown]
# ### 338 딕셔너리 조건부 업데이트

# %% [markdown]
# 아래 딕셔너리에서 값이 0 이하인 항목은 삭제하고, 양수인 항목은 값을 2배로 만드세요.
# ```python
# d={'사과':3,'배':-1,'딸기':0,'포도':5,'망고':2}
# # 결과: {'사과':6,'포도':10,'망고':4}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# d={'사과':3,'배':-1,'딸기':0,'포도':5,'망고':2}
# result={k:v*2 for k,v in d.items() if v>0}
# print(result)
# </pre>
# </details>

# %%
d={'사과':3,'배':-1,'딸기':0,'포도':5,'망고':2}
# 여기에 코드를 작성하세요
result={k:v*2 for k,v in d.items() if v>0}
print(result)
# Out:
# {'사과': 6, '포도': 10, '망고': 4}

# %% [markdown]
# ### 339 딕셔너리로 투표 집계

# %% [markdown]
# 투표 결과 리스트에서 후보별 득표수와 승자를 출력하세요.
# ```python
# votes=['김파이','이파이','김파이','박파이','이파이','김파이','김파이']
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# from collections import Counter
# votes=['김파이','이파이','김파이','박파이','이파이','김파이','김파이']
# result=Counter(votes)
# for name,cnt in result.most_common():
#     print(f'{name}: {cnt}표')
# print('당선:', result.most_common(1)[0][0])
# </pre>
# </details>

# %%
from collections import Counter
votes=['김파이','이파이','김파이','박파이','이파이','김파이','김파이']
# 여기에 코드를 작성하세요
result=Counter(votes)
for name,cnt in result.most_common():
    print(f'{name}: {cnt}표')
print('당선:', result.most_common(1)[0][0])
# Out:
# 김파이: 4표
# 이파이: 2표
# 박파이: 1표
# 당선: 김파이

# %% [markdown]
# ### 340 딕셔너리 직렬화 (JSON)

# %% [markdown]
# 딕셔너리를 JSON 문자열로 변환하고, 다시 딕셔너리로 변환하세요.
# ```python
# data={'name':'김파이','scores':[85,92,78],'active':True}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# import json
# data={'name':'김파이','scores':[85,92,78],'active':True}
#
# json_str=json.dumps(data, ensure_ascii=False)
# print(type(json_str), json_str)
#
# back=json.loads(json_str)
# print(type(back), back)
# </pre>
# </details>

# %%
import json
data={'name':'김파이','scores':[85,92,78],'active':True}
# 여기에 코드를 작성하세요

json_str=json.dumps(data, ensure_ascii=False)
print(type(json_str), json_str)

back=json.loads(json_str)
print(type(back), back)
# Out:
# <class 'str'> {"name": "김파이", "scores": [85, 92, 78], "active": true}
# <class 'dict'> {'name': '김파이', 'scores': [85, 92, 78], 'active': True}
