# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 11. 파이썬 클래스 (271 ~ 280) - Account 클래스
#
# > 이번 파트는 271번부터 280번까지 은행 계좌(Account) 클래스를 단계적으로 완성해 나갑니다.

# %% [markdown]
# ### 271 Account 클래스 - 생성자

# %% [markdown]
# 은행에 가서 계좌를 개설하면 은행이름, 예금주, 계좌번호, 잔액이 설정됩니다. Account 클래스를 생성한 후 생성자를 구현해보세요. 생성자에서는 예금주와 초기 잔액만 입력 받습니다. 은행이름은 'SC은행'으로, 계좌번호는 3자리-2자리-6자리 형태로 랜덤하게 생성됩니다.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# zfill(n)은 숫자를 n자리 문자열로 만들어줍니다. (빈 자리는 0으로 채움)</br>
# <pre>
# import random
#
# class Account:
#     def __init__(self, name, balance):
#         self.name = name
#         self.balance = balance
#         self.bank = "SC은행"
#         num1 = str(random.randint(0, 999)).zfill(3)
#         num2 = str(random.randint(0, 99)).zfill(2)
#         num3 = str(random.randint(0, 999999)).zfill(6)
#         self.account_number = num1 + '-' + num2 + '-' + num3
#
# kim = Account("김민수", 100)
# print(kim.name, kim.balance, kim.bank, kim.account_number)
# </pre>
# </details>

# %%
import random

# # 여기에 Account 클래스를 작성하세요

class Account:
    def __init__(self, name, balance):
        self.name = name
        self.balance = balance

        self.bank = "SC은행"

        num1 = str(random.randint(0, 999)).zfill(3)  # 0부터 999까지 랜덤한 숫자를 내보내고 문자열이 3자리가 될 때까지 0으로 채워라
        num2 = str(random.randint(0, 99)).zfill(2)
        num3 = str(random.randint(0, 999999)).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3


kim = Account("김민수", 100)
print(kim.name, kim.balance, kim.bank, kim.account_number)
# Out:
# 김민수 100 SC은행 962-34-768290

# %% [markdown]
# ### 272 클래스 변수 - 계좌 개수

# %% [markdown]
# 클래스 변수를 사용해서 Account 클래스로부터 생성된 계좌 객체의 개수를 저장하세요.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 클래스 변수는 모든 인스턴스가 공유합니다. Account.account_count로 접근합니다.</br>
# <pre>
# class Account:
#     account_count = 0  # 클래스 변수
#
#     def __init__(self, name, balance):
#         # ... 생략 ...
#         Account.account_count += 1
#
# kim = Account("김민수", 100)
# print(Account.account_count)  # 1
# lee = Account("이민수", 100)
# print(Account.account_count)  # 2
# </pre>
# </details>

# %%
import random

# # 여기에 Account 클래스를 작성하세요

class Account:
    account_count = 0  # 클래스 변수

    def __init__(self, name, balance):
        self.name = name
        self.balance = balance

        self.bank = "SC은행"

        num1 = str(random.randint(0, 999)).zfill(3)  # 0부터 999까지 랜덤한 숫자를 내보내고 문자열이 3자리가 될 때까지 0으로 채워라
        num2 = str(random.randint(0, 99)).zfill(2)
        num3 = str(random.randint(0, 999999)).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

        Account.account_count += 1


kim = Account("김민수", 100)
print(Account.account_count)  # 1


lee = Account("이민수", 100)
print(Account.account_count)  # 2
# Out:
# 1
# 2

# %% [markdown]
# ### 273 클래스 메서드 - get_account_num()

# %% [markdown]
# Account 클래스로부터 생성된 계좌의 개수를 출력하는 get_account_num() 클래스 메서드를 추가하세요.
# ```
# 실행 예:
# kim.get_account_num()  # 2
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# @classmethod 데코레이터와 cls 파라미터를 사용합니다.</br>
# <pre>
# @classmethod
# def get_account_num(cls):
#     print(cls.account_count)
# </pre>
# </details>

# %%
import random

# 여기에 코드를 작성하세요

class Account:
    account_count = 0  # 클래스 변수

    def __init__(self, name, balance):
        self.name = name
        self.balance = balance

        self.bank = "SC은행"

        num1 = str(random.randint(0, 999)).zfill(3)
        num2 = str(random.randint(0, 99)).zfill(2)
        num3 = str(random.randint(0, 999999)).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
      print(cls.account_count)

# %% [markdown]
# ### 274 입금 메서드 - deposit()

# %% [markdown]
# Account 클래스에 입금을 위한 deposit 메서드를 추가하세요. 입금은 최소 1원 이상만 가능합니다.
# ```
# 실행 예:
# k = Account("kim", 100)
# k.deposit(200)
# print(k.balance)  # 300
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# def deposit(self, amount):
#     if amount >= 1:
#         self.balance += amount
# </pre>
# </details>

# %%
import random

# 여기에 코드를 작성하세요
class Account:
    account_count = 0  # 클래스 변수

    def __init__(self, name, balance):
        self.name = name
        self.balance = balance

        self.bank = "SC은행"

        num1 = str(random.randint(0, 999)).zfill(3)
        num2 = str(random.randint(0, 99)).zfill(2)
        num3 = str(random.randint(0, 999999)).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
      print(cls.account_count)

    def deposit(self, amount):
      if amount >= 1:
        self.balance += amount

k = Account("kim", 100)
k.deposit(200)
print(k.balance)  # 300
# Out:
# 100

# %% [markdown]
# ### 275 출금 메서드 - withdraw()

# %% [markdown]
# Account 클래스에 출금을 위한 withdraw 메서드를 추가하세요. 출금은 계좌의 잔고 이상으로 출금할 수는 없습니다.
# ```
# 실행 예:
# k = Account("kim", 100)
# k.deposit(100)
# k.withdraw(90)
# print(k.balance)  # 110
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# def withdraw(self, amount):
#     if self.balance > amount:
#         self.balance -= amount
# </pre>
# </details>

# %%
import random

# 여기에 코드를 작성하세요
class Account:
    account_count = 0  # 클래스 변수

    def __init__(self, name, balance):
        self.name = name
        self.balance = balance

        self.bank = "SC은행"

        num1 = str(random.randint(0, 999)).zfill(3)
        num2 = str(random.randint(0, 99)).zfill(2)
        num3 = str(random.randint(0, 999999)).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
      print(cls.account_count)

    def deposit(self, amount):
      if amount >= 1:
        self.balance += amount

    def withdraw(self, amount):
      if self.balance > amount:
        self.balance -= amount

k = Account("kim", 100)
k.deposit(100)
k.withdraw(90)
print(k.balance)  # 110
# Out:
# 200

# %% [markdown]
# ### 276 정보 출력 메서드 - display_info()

# %% [markdown]
# Account 인스턴스에 저장된 정보를 출력하는 display_info() 메서드를 추가하세요. 잔고는 세 자리마다 쉼표를 출력하세요.
# ```
# 실행 예:
# 은행이름:  SC은행
# 예금주:  파이썬
# 계좌번호:  xxx-xx-xxxxxx
# 잔고:  10,000
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# f"{숫자:,}" 또는 format(숫자, ',')으로 천 단위 콤마를 표시합니다.</br>
# <pre>
# def display_info(self):
#     print("은행이름: ", self.bank)
#     print("예금주: ", self.name)
#     print("계좌번호: ", self.account_number)
#     print("잔고: ", f"{self.balance:,}")
# </pre>
# </details>

# %%
import random

# 여기에 코드를 작성하세요

class Account:
    account_count = 0  # 클래스 변수

    def __init__(self, name, balance):
        self.name = name
        self.balance = balance

        self.bank = "SC은행"

        num1 = str(random.randint(0, 999)).zfill(3)
        num2 = str(random.randint(0, 99)).zfill(2)
        num3 = str(random.randint(0, 999999)).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
      print(cls.account_count)

    def deposit(self, amount):
      if amount >= 1:
        self.balance += amount

    def withdraw(self, amount):
      if self.balance > amount:
        self.balance -= amount

    def display_info(self):
      print("은행이름: ", self.bank)
      print("예금주: ", self.name)
      print("계좌번호: ", self.account_number)
      print("잔고: ", f"{self.balance:,}")

k = Account("kim", 100)
k.deposit(100)
k.withdraw(90)
k.display_info()
# Out:
# 은행이름:  SC은행
# 예금주:  kim
# 계좌번호:  412-94-646065
# 잔고:  110

# %% [markdown]
# ### 277 이자 지급하기

# %% [markdown]
# 입금 횟수가 5회가 될 때마다 잔고를 기준으로 1%의 이자가 잔고에 추가되도록 코드를 변경해보세요.
# ```
# 실행 예:
# p = Account("파이썬", 10000)
# p.deposit(10000)  # 1회
# p.deposit(10000)  # 2회
# p.deposit(10000)  # 3회
# p.deposit(5000)   # 4회
# p.deposit(5000)   # 5회 → 이자 지급!
# print(p.balance)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 입금 횟수를 카운트하고 5의 배수일 때 1% 이자를 추가합니다.</br>
# <pre>
# def __init__(self, name, balance):
#     self.deposit_count = 0
#     # ... 나머지 코드 ...
#
# def deposit(self, amount):
#     if amount >= 1:
#         self.balance += amount
#         self.deposit_count += 1
#         if self.deposit_count % 5 == 0:
#             self.balance = self.balance * 1.01
# </pre>
# </details>

# %%
import random

# 여기에 코드를 작성하세요

class Account:
    account_count = 0  # 클래스 변수

    def __init__(self, name, balance):
        self.name = name
        self.balance = balance
        self.deposit_count = 0 # deposit_count 초기화

        self.bank = "SC은행"

        num1 = str(random.randint(0, 999)).zfill(3)
        num2 = str(random.randint(0, 99)).zfill(2)
        num3 = str(random.randint(0, 999999)).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
      print(cls.account_count)

    def withdraw(self, amount):
      if self.balance > amount:
        self.balance -= amount

    def display_info(self):
      print("은행이름: ", self.bank)
      print("예금주: ", self.name)
      print("계좌번호: ", self.account_number)
      print("잔고: ", f"{self.balance:,}")

    def deposit(self, amount):
      if amount >= 1:
        self.balance += amount
        self.deposit_count += 1
        if self.deposit_count % 5 == 0:
            self.balance = self.balance * 1.01

p = Account("파이썬", 10000)

p.deposit(10000)  # 1회
print(p.balance)
p.deposit(10000)  # 2회
print(p.balance)
p.deposit(10000)  # 3회
print(p.balance)
p.deposit(5000)   # 4회
print(p.balance)
p.deposit(5000)   # 5회
print(p.balance)
# Out:
# 20000
# 30000
# 40000
# 45000
# 50500.0

# %% [markdown]
# ### 278 여러 객체 생성 및 리스트 저장

# %% [markdown]
# Account 클래스로부터 3개 이상 인스턴스를 생성하고 생성된 인스턴스를 리스트에 저장해보세요.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# data = []
# k = Account("KIM", 10000000)
# l = Account("LEE", 10000)
# p = Account("PARK", 10000)
# data.append(k)
# data.append(l)
# data.append(p)
# print(len(data))  # 3
# </pre>
# </details>

# %%
import random

class Account:
    account_count = 0
    def __init__(self, name, balance):
        self.deposit_count = 0
        self.name = name
        self.balance = balance
        self.bank = "SC은행"
        num1 = str(random.randint(0, 999)).zfill(3)
        num2 = str(random.randint(0, 99)).zfill(2)
        num3 = str(random.randint(0, 999999)).zfill(6)
        self.account_number = num1 + '-' + num2 + '-' + num3
        Account.account_count += 1
    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
    def withdraw(self, amount):
        if self.balance > amount:
            self.balance -= amount
    def display_info(self):
        print("은행이름: ", self.bank)
        print("예금주: ", self.name)
        print("계좌번호: ", self.account_number)
        print("잔고: ", f"{self.balance:,}")

# 3개 이상 인스턴스를 생성하고 리스트에 저장하세요
data = []
k = Account("KIM", 10000000)
l = Account("LEE", 10000)
p = Account("PARK", 10000)
data.append(k)
data.append(l)
data.append(p)

print(len(data))  # 3
print()
print(data)
print()
for account in data:
    account.display_info()
    print()  # 줄바꿈 (계좌 사이 구분용)
# Out:
# 3
#
# [<__main__.Account object at 0x7c12efd699d0>, <__main__.Account object at 0x7c12efd690d0>, <__main__.Account object at 0x7c12efd6ac30>]
#
# 은행이름:  SC은행
# 예금주:  KIM
# 계좌번호:  327-70-416325
# 잔고:  10,000,000
#
# 은행이름:  SC은행
# 예금주:  LEE
# 계좌번호:  497-27-805465
# 잔고:  10,000
#
# 은행이름:  SC은행
# 예금주:  PARK
# 계좌번호:  204-85-703872
# 잔고:  10,000

# %% [markdown]
# ### 279 조건부 객체 순회 출력

# %% [markdown]
# 반복문을 통해 리스트에 있는 객체를 순회하면서 잔고가 100만원 이상인 고객의 정보만 출력하세요.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# for c in data:
#     if c.balance >= 1000000:
#         c.display_info()
# </pre>
# </details>

# %%
import random

class Account:
    account_count = 0
    def __init__(self, name, balance):
        self.name = name
        self.balance = balance
        self.bank = "SC은행"
        num1 = str(random.randint(0, 999)).zfill(3)
        num2 = str(random.randint(0, 99)).zfill(2)
        num3 = str(random.randint(0, 999999)).zfill(6)
        self.account_number = num1 + '-' + num2 + '-' + num3
        Account.account_count += 1
    def display_info(self):
        print(f"예금주: {self.name}, 잔고: {self.balance:,}원")

data = []
data.append(Account("KIM", 10000000))
data.append(Account("LEE", 10000))
data.append(Account("PARK", 500000))

# 잔고 100만원 이상인 고객만 출력하세요
for c in data:
    if c.balance >= 1000000:
        c.display_info()
# Out:
# 예금주: KIM, 잔고: 10,000,000원

# %% [markdown]
# ### 280 입출금 내역 기록 메서드

# %% [markdown]
# 입금과 출금 내역이 기록되도록 코드를 업데이트 하세요. 입금 내역과 출금 내역을 출력하는 deposit_history와 withdraw_history 메서드를 추가하세요.
# ```
# 실행 예:
# k.deposit(100)
# k.deposit(200)
# k.deposit_history()
# # 100
# # 200
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 생성자에서 빈 로그 리스트를 초기화하고, 입출금 시 append합니다.</br>
# <pre>
# def __init__(self, ...):
#     self.deposit_log = []
#     self.withdraw_log = []
#     # ...
#
# def deposit(self, amount):
#     if amount >= 1:
#         self.deposit_log.append(amount)
#         self.balance += amount
#
# def withdraw(self, amount):
#     if self.balance > amount:
#         self.withdraw_log.append(amount)
#         self.balance -= amount
#
# def deposit_history(self):
#     for amount in self.deposit_log:
#         print(amount)
#
# def withdraw_history(self):
#     for amount in self.withdraw_log:
#         print(amount)
# </pre>
# </details>

# %%
import random

# 여기에 코드를 작성하세요
import random

class Account:
    account_count = 0
    def __init__(self, name, balance):
        self.deposit_log = []
        self.withdraw_log = []
        self.deposit_count = 0
        self.name = name
        self.balance = balance
        self.bank = "SC은행"
        num1 = str(random.randint(0, 999)).zfill(3)
        num2 = str(random.randint(0, 99)).zfill(2)
        num3 = str(random.randint(0, 999999)).zfill(6)
        self.account_number = num1 + '-' + num2 + '-' + num3
        Account.account_count += 1
    def deposit(self, amount):
      if amount >= 1:
        self.deposit_log.append(amount)
        self.balance += amount


    def withdraw(self, amount):
      if self.balance > amount:
        self.withdraw_log.append(amount)
        self.balance -= amount


    def deposit_history(self):
      for amount in self.deposit_log:
        print(amount)


    def withdraw_history(self):
      for amount in self.withdraw_log:
        print(amount)
    def display_info(self):
        print("은행이름: ", self.bank)
        print("예금주: ", self.name)
        print("계좌번호: ", self.account_number)
        print("잔고: ", f"{self.balance:,}")

k = Account("KIM", 0)
k.deposit(100)
k.deposit(200)
k.deposit_history()
# 100
# 200
# Out:
# 100
# 200
