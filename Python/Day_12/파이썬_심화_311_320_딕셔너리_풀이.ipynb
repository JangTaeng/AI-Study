# %% [markdown]
# # 파이썬 심화 문제집 - 딕셔너리

# %% [markdown]
# ## 딕셔너리 심화 (311 ~ 320)

# %% [markdown]
# ### 311 공통 키 찾기

# %% [markdown]
# 두 딕셔너리에서 공통된 키를 찾아 출력하세요.
# ```python
# d1 = {'a':1,'b':2,'c':3}
# d2 = {'b':20,'c':30,'d':40}
# # 결과: {'b','c'}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# d1={'a':1,'b':2,'c':3}
# d2={'b':20,'c':30,'d':40}
# print(d1.keys() & d2.keys())  # {'b','c'}
# </pre>
# </details>

# %%
d1 = {'a':1,'b':2,'c':3}
d2 = {'b':20,'c':30,'d':40}
# 여기에 코드를 작성하세요
print(d1.keys() & d2.keys())
# Out:
# {'c', 'b'}

# %% [markdown]
# ### 312 값 합계와 평균

# %% [markdown]
# 딕셔너리의 모든 값의 합계와 평균을 구하세요.
# ```python
# scores = {'민수':85,'지영':62,'철수':91,'수연':55,'태호':78}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# scores={'민수':85,'지영':62,'철수':91,'수연':55,'태호':78}
# total=sum(scores.values())
# print(f'합계:{total}, 평균:{total/len(scores):.1f}')
# </pre>
# </details>

# %%
scores={'민수':85,'지영':62,'철수':91,'수연':55,'태호':78}
# 여기에 코드를 작성하세요
total=sum(scores.values())
print(f'합계:{total}, 평균:{total/len(scores):.1f}')
# Out:
# 합계:371, 평균:74.2

# %% [markdown]
# ### 313 키/값 뒤집기

# %% [markdown]
# 딕셔너리의 키와 값을 서로 바꾸세요.
# ```python
# d = {'a':1,'b':2,'c':3}
# # 결과: {1:'a',2:'b',3:'c'}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# d={'a':1,'b':2,'c':3}
# print({v:k for k,v in d.items()})
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
d={'a':1,'b':2,'c':3}
print({v:k for k,v in d.items()})
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %% [markdown]
# ### 314 학점별 그룹화

# %% [markdown]
# 학생 리스트를 학점별로 그룹화하세요.
# ```python
# students=[('민수','A'),('지영','B'),('철수','A'),('수연','C'),('태호','B')]
# # 결과: {'A':['민수','철수'],'B':['지영','태호'],'C':['수연']}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# students=[('민수','A'),('지영','B'),('철수','A'),('수연','C'),('태호','B')]
# groups={}
# for name,grade in students:
#     groups.setdefault(grade,[]).append(name)
# print(groups)
# </pre>
# </details>

# %%
students=[('민수','A'),('지영','B'),('철수','A'),('수연','C'),('태호','B')]
# 여기에 코드를 작성하세요
groups={}
for name,grade in students:
    groups.setdefault(grade,[]).append(name)
print(groups)
# Out:
# {'A': ['민수', '철수'], 'B': ['지영', '태호'], 'C': ['수연']}

# %% [markdown]
# ### 315 최댓값/최솟값 키 찾기

# %% [markdown]
# 딕셔너리에서 가장 높은 점수와 가장 낮은 점수의 학생을 출력하세요.
# ```python
# scores={'민수':85,'지영':62,'철수':91,'수연':55,'태호':78}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# scores={'민수':85,'지영':62,'철수':91,'수연':55,'태호':78}
# print('최고:', max(scores, key=scores.get))
# print('최저:', min(scores, key=scores.get))
# </pre>
# </details>

# %%
scores={'민수':85,'지영':62,'철수':91,'수연':55,'태호':78}
# 여기에 코드를 작성하세요

print('최고:', max(scores, key=scores.get))
print('최저:', min(scores, key=scores.get))
# Out:
# 최고: 철수
# 최저: 수연

# %% [markdown]
# ### 316 딕셔너리 깊은 복사

# %% [markdown]
# 얕은 복사와 깊은 복사의 차이를 확인하세요.
# ```python
# original = {'name':'김파이', 'scores':[85,90,78]}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# import copy
# d={'name':'김파이','scores':[85,90,78]}
# shallow=d.copy()
# shallow['scores'].append(100)
# print('얕은 복사 후 원본:', d['scores'])  # 영향받음!
#
# d2={'name':'김파이','scores':[85,90,78]}
# deep=copy.deepcopy(d2)
# deep['scores'].append(100)
# print('깊은 복사 후 원본:', d2['scores'])  # 영향없음
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
import copy
d={'name':'김파이','scores':[85,90,78]}
shallow=d.copy()
shallow['scores'].append(100)
print('얕은 복사 후 원본:', d['scores'])  # 영향받음!

d2={'name':'김파이','scores':[85,90,78]}
deep=copy.deepcopy(d2)
deep['scores'].append(100)
print('깊은 복사 후 원본:', d2['scores'])  # 영향없음
# Out:
# 얕은 복사 후 원본: [85, 90, 78, 100]
# 깊은 복사 후 원본: [85, 90, 78]

# %% [markdown]
# ### 317 딕셔너리로 통계 계산

# %% [markdown]
# 주식 데이터 리스트에서 종목별 평균 종가를 계산하세요.
# ```python
# data=[{'code':'005930','close':70000},{'code':'005930','close':71000},
#       {'code':'035420','close':350000},{'code':'035420','close':360000}]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# data=[{'code':'005930','close':70000},{'code':'005930','close':71000},
#       {'code':'035420','close':350000},{'code':'035420','close':360000}]
# totals={}
# counts={}
# for item in data:
#     c=item['code']
#     totals[c]=totals.get(c,0)+item['close']
#     counts[c]=counts.get(c,0)+1
# for c in totals:
#     print(c, f'{totals[c]/counts[c]:,.0f}원')
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
data=[{'code':'005930','close':70000},{'code':'005930','close':71000},
      {'code':'035420','close':350000},{'code':'035420','close':360000}]
totals={}
counts={}
for item in data:
    c=item['code']
    totals[c]=totals.get(c,0)+item['close']
    counts[c]=counts.get(c,0)+1
for c in totals:
    print(c, f'{totals[c]/counts[c]:,.0f}원')
# Out:
# 005930 70,500원
# 035420 355,000원

# %% [markdown]
# ### 318 중첩 딕셔너리에 평균 추가

# %% [markdown]
# 학생별 과목 점수 딕셔너리에 'avg' 키를 추가하세요.
# ```python
# students={'민수':{'국어':85,'수학':92},'지영':{'국어':90,'수학':65}}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# students={'민수':{'국어':85,'수학':92},'지영':{'국어':90,'수학':65}}
# for name,scores in students.items():
#     scores['avg']=round(sum(scores.values())/len(scores),1)
# print(students)
# </pre>
# </details>

# %%
students={'민수':{'국어':85,'수학':92},'지영':{'국어':90,'수학':65}}
# 여기에 코드를 작성하세요

for name,scores in students.items():
    scores['avg']=round(sum(scores.values())/len(scores),1)
print(students)
# Out:
# {'민수': {'국어': 85, '수학': 92, 'avg': 88.5}, '지영': {'국어': 90, '수학': 65, 'avg': 77.5}}

# %% [markdown]
# ### 319 defaultdict 활용

# %% [markdown]
# collections.defaultdict를 사용해 단어 빈도수를 구하세요.
# ```python
# words=['apple','banana','apple','cherry','banana','apple']
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# from collections import defaultdict
# words=['apple','banana','apple','cherry','banana','apple']
# count=defaultdict(int)
# for w in words:
#     count[w]+=1
# print(dict(count))
# </pre>
# </details>

# %%
from collections import defaultdict
words=['apple','banana','apple','cherry','banana','apple']
# 여기에 코드를 작성하세요

count=defaultdict(int)
for w in words:
    count[w]+=1
print(dict(count))
# Out:
# {'apple': 3, 'banana': 2, 'cherry': 1}

# %% [markdown]
# ### 320 딕셔너리 역순 출력

# %% [markdown]
# 딕셔너리를 삽입 역순으로 출력하세요.
# ```python
# d = {'c':3,'a':1,'b':2}
# # 역순: b,a,c
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# d={'c':3,'a':1,'b':2}
# for k in reversed(list(d.keys())):
#     print(k, d[k])
# </pre>
# </details>

# %%
d={'c':3,'a':1,'b':2}
# 여기에 코드를 작성하세요

for k in reversed(list(d.keys())):
    print(k, d[k])
# Out:
# b 2
# a 1
# c 3
