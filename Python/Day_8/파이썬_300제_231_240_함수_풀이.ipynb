# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 09. 파이썬 함수 (231 ~ 240) - return

# %% [markdown]
# ### 231 지역 변수 오류 예측

# %% [markdown]
# 아래 코드를 실행한 결과를 예상하라.
# ```python
# def n_plus_1(n):
#     result = n + 1
#
# n_plus_1(3)
# print(result)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 함수 내부에서 선언된 변수(result)는 함수 밖에서 접근할 수 없습니다(지역 변수). 함수 내부 값을 외부로 전달하려면 return을 사용해야 합니다.</br>
# <pre>
# # 결과: NameError: name 'result' is not defined
#
# # 올바른 방법 (return 사용):
# def n_plus_1(n):
#     result = n + 1
#     return result
#
# result = n_plus_1(3)
# print(result)  # 4
# </pre>
# </details>

# %%
# 아래 코드를 실행해서 에러를 확인
def n_plus_1(n):
    result = n + 1

result = n_plus_1(3)
print(result)

# 리턴이 n인데 없어서  None
# Out:
# None

# %%
# 아래 코드를 실행해서 에러를 확인하고, return을 사용해 수정해보세요
def n_plus_1(n):
    result = n + 1
    return result  # return 추가

result = n_plus_1(3)
print(result)

# 4
# Out:
# 4

# %% [markdown]
# ### 232 URL 생성 함수 (return)

# %% [markdown]
# 문자열 하나를 입력받아 인터넷 주소를 반환하는 make_url 함수를 정의하라.
# ```
# 실행 예:
# make_url("naver")
# www.naver.com
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# def make_url(string):
#     return "www." + string + ".com"
#
# print(make_url("naver"))
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
def make_url(s):
    return "www." + s + ".com"

print(make_url("naver"))
# Out:
# www.naver.com

# %% [markdown]
# ### 233 문자열 → 리스트 변환 함수

# %% [markdown]
# 문자열을 입력받아 각 문자들로 구성된 리스트로 반환하는 make_list 함수를 정의하라.
# ```
# 실행 예:
# make_list("abcd")
# ['a', 'b', 'c', 'd']
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# def make_list(string):
#     my_list = []
#     for 변수 in string:
#         my_list.append(변수)
#     return my_list
#
# # 또는 간단하게:
# def make_list(string):
#     return list(string)
#
# print(make_list("abcd"))
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
def make_list(s):
    list=[]
    for i in s:
        list.append(i)
    return list

print(make_list("abcd"))
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# ### 234 짝수 추출 함수

# %% [markdown]
# 숫자로 구성된 하나의 리스트를 입력받아, 짝수들을 추출하여 리스트로 반환하는 pickup_even 함수를 구현하라.
# ```
# 실행 예:
# pickup_even([3, 4, 5, 6, 7, 8])
# [4, 6, 8]
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# def pickup_even(items):
#     result = []
#     for item in items:
#         if item % 2 == 0:
#             result.append(item)
#     return result
#
# print(pickup_even([3, 4, 5, 6, 7, 8]))
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
def pickup_even(items):
    result = []
    for i in items:
        if i % 2 == 0:
            result.append(i)
    return result

pickup_even([3, 4, 5, 6, 7, 8])
# Out:
# [4, 6, 8]

# %% [markdown]
# ### 235 콤마 제거 정수 변환 함수

# %% [markdown]
# 콤마가 포함된 문자열 숫자를 입력받아 정수로 변환하는 convert_int 함수를 정의하라.
# ```
# 실행 예:
# convert_int("1,234,567")
# 1234567
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# replace()로 콤마를 제거한 뒤 int()로 변환합니다.</br>
# <pre>
# def convert_int(string):
#     return int(string.replace(',', ''))
#
# print(convert_int("1,234,567"))
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
def convert_int(s):
    return int(s.replace(',',''))

convert_int("1,234,567")
# Out:
# 1234567

# %% [markdown]
# ### 236 return 값 연속 사용 - 결과 예측

# %% [markdown]
# 아래 코드의 실행 결과를 예측하라.
# ```python
# def 함수(num):
#     return num + 4
#
# a = 함수(10)
# b = 함수(a)
# c = 함수(b)
# print(c)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 함수(10)→14, 함수(14)→18, 함수(18)→22</br>
# <pre>
# # 결과: 22
# </pre>
# </details>

# %%
def 함수(num):
    return num + 4

a = 함수(10)  # 14
b = 함수(a)   # 18
c = 함수(b)   # 22
print(c)     # 22
# Out:
# 22

# %% [markdown]
# ### 237 중첩 함수 호출 - 결과 예측

# %% [markdown]
# 아래 코드의 실행 결과를 예측하라.
# ```python
# def 함수(num):
#     return num + 4
#
# c = 함수(함수(함수(10)))
# print(c)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 안쪽부터 순서대로: 함수(10)=14, 함수(14)=18, 함수(18)=22</br>
# <pre>
# # 결과: 22
# </pre>
# </details>

# %%
def 함수(num):
    return num + 4

c = 함수(함수(함수(10)))  # c = (14)+4+4
print(c) # 22
# Out:
# 22

# %% [markdown]
# ### 238 두 함수 연결 - 결과 예측

# %% [markdown]
# 아래 코드의 실행 결과를 예측하라.
# ```python
# def 함수1(num):
#     return num + 4
#
# def 함수2(num):
#     return num * 10
#
# a = 함수1(10)
# c = 함수2(a)
# print(c)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 함수1(10)=14, 함수2(14)=140</br>
# <pre>
# # 결과: 140
# </pre>
# </details>

# %%
def 함수1(num):
    return num + 4

def 함수2(num):
    return num * 10

a = 함수1(10)       # 14
c = 함수2(a)        # 140
print(c)            # 140
# Out:
# 140

# %% [markdown]
# ### 239 함수 안에서 함수 호출 - 결과 예측

# %% [markdown]
# 아래 코드의 실행 결과를 예측하라.
# ```python
# def 함수1(num):
#     return num + 4
#
# def 함수2(num):
#     num = num + 2
#     return 함수1(num)
#
# c = 함수2(10)
# print(c)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 함수2(10) → num=10+2=12 → 함수1(12) → 12+4=16 반환</br>
# <pre>
# # 결과: 16
# </pre>
# </details>

# %%
def 함수1(num):
    return num + 4

def 함수2(num):
    num = num + 2
    return 함수1(num)

c = 함수2(10)     # 16
print(c)
# Out:
# 16

# %% [markdown]
# ### 240 삼중 함수 연결 - 결과 예측

# %% [markdown]
# 아래 코드의 실행 결과를 예측하라.
# ```python
# def 함수0(num):
#     return num * 2
#
# def 함수1(num):
#     return 함수0(num + 2)
#
# def 함수2(num):
#     num = num + 10
#     return 함수1(num)
#
# c = 함수2(2)
# print(c)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 함수2(2) → num=2+10=12 → 함수1(12) → 함수0(12+2)=함수0(14) → 14*2=28</br>
# <pre>
# # 결과: 28
# </pre>
# </details>

# %%
def 함수0(num):
    return num * 2

def 함수1(num):
    return 함수0(num + 2)

def 함수2(num):
    num = num + 10
    return 함수1(num)

c = 함수2(2)    # 28
print(c)
# Out:
# 28
