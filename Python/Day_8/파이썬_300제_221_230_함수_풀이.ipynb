# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 09. 파이썬 함수 (221 ~ 230)

# %% [markdown]
# ### 221 문자열 역순 출력 함수

# %% [markdown]
# 입력된 문자열을 역순으로 출력하는 print_reverse 함수를 정의하라.
# ```
# 실행 예:
# print_reverse("python")
# nohtyp
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 슬라이싱 [::-1]을 사용하면 문자열을 역순으로 얻을 수 있습니다.</br>
# <pre>
# def print_reverse(string):
#     print(string[::-1])
#
# print_reverse("python")
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
def print_reverse(string):
    print(string[::-1])

print_reverse("python")
# Out:
# nohtyp

# %% [markdown]
# ### 222 평균 출력 함수

# %% [markdown]
# 성적 리스트를 입력받아 평균을 출력하는 print_score 함수를 정의하라.
# ```
# 실행 예:
# print_score([1, 2, 3])
# 2.0
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# sum()과 len()을 활용합니다.</br>
# <pre>
# def print_score(score_list):
#     print(sum(score_list) / len(score_list))
#
# print_score([1, 2, 3])
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
def print_score(list):
  print(sum(list)/len(list))

print_score([1,2,3])
# Out:
# 2.0

# %% [markdown]
# ### 223 짝수만 출력 함수

# %% [markdown]
# 하나의 리스트를 입력받아 짝수만 화면에 출력하는 print_even 함수를 정의하라.
# ```
# 실행 예:
# print_even([1, 3, 2, 10, 12, 11, 15])
# 2
# 10
# 12
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# for문과 if문을 함께 사용합니다.</br>
# <pre>
# def print_even(my_list):
#     for v in my_list:
#         if v % 2 == 0:
#             print(v)
#
# print_even([1, 3, 2, 10, 12, 11, 15])
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
def print_even(list):
  i = 0
  for i in list:
    if(i % 2 == 0):
      print(i)

print_even([1, 3, 2, 10, 12, 11, 15])
# Out:
# 2
# 10
# 12

# %% [markdown]
# ### 224 딕셔너리 키 출력 함수

# %% [markdown]
# 하나의 딕셔너리를 입력받아 딕셔너리의 key 값을 화면에 출력하는 print_keys 함수를 정의하라.
# ```
# 실행 예:
# print_keys({"이름":"김말똥", "나이":30, "성별":0})
# 이름
# 나이
# 성별
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# def print_keys(dic):
#     for key in dic.keys():
#         print(key)
#
# print_keys({"이름":"김말똥", "나이":30, "성별":0})
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
def print_keys(dict):
  for i in dict.keys():
    print(i)

print_keys({"이름":"김말똥", "나이":30, "성별":0})
# Out:
# 이름
# 나이
# 성별

# %% [markdown]
# ### 225 키로 값 조회 함수

# %% [markdown]
# my_dict와 날짜 키값을 입력받아 OHLC 리스트를 출력하는 print_value_by_key 함수를 정의하라.
# ```python
# my_dict = {"10/26": [100, 130, 100, 100],
#            "10/27": [10, 12, 10, 11]}
# ```
# ```
# 실행 예:
# print_value_by_key(my_dict, "10/26")
# [100, 130, 100, 100]
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# def print_value_by_key(my_dict, key):
#     print(my_dict[key])
#
# my_dict = {"10/26": [100, 130, 100, 100], "10/27": [10, 12, 10, 11]}
# print_value_by_key(my_dict, "10/26")
# </pre>
# </details>

# %%
my_dict = {"10/26": [100, 130, 100, 100], "10/27": [10, 12, 10, 11]}
# 여기에 코드를 작성하세요
def print_value_by_key(dict,key):
  print(dict[key])

print_value_by_key(my_dict,"10/26")
# Out:
# [100, 130, 100, 100]

# %% [markdown]
# ### 226 5글자씩 출력 함수

# %% [markdown]
# 입력 문자열을 한 줄에 다섯 글자씩 출력하는 print_5xn(string) 함수를 작성하라.
# ```
# 실행 예:
# print_5xn("아이엠어보이유알어걸")
# 아이엠어보
# 이유알어걸
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 슬라이싱으로 5글자씩 잘라서 출력합니다.</br>
# <pre>
# def print_5xn(line):
#     chunk_num = int(len(line) / 5)
#     for x in range(chunk_num + 1):
#         print(line[x * 5: x * 5 + 5])
#
# print_5xn("아이엠어보이유알어걸")
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
def print_5xn(string):
  gul = int(len(string)/5)
  for x in range(gul+1):
    print(string[x*5:x*5+5])

print_5xn("아이엠어보이유알어걸")
# Out:
# 아이엠어보
# 이유알어걸

# %% [markdown]
# ### 227 n글자씩 출력 함수

# %% [markdown]
# 문자열과 한 줄에 출력될 글자 수를 입력받아 한 줄에 해당 글자 수만큼 출력하는 print_mxn(string, num) 함수를 작성하라.
# ```
# 실행 예:
# print_mxn("아이엠어보이유알어걸", 3)
# 아이엠
# 어보이
# 유알어
# 걸
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 226번을 일반화한 함수입니다.</br>
# <pre>
# def print_mxn(line, num):
#     chunk_num = int(len(line) / num)
#     for x in range(chunk_num + 1):
#         print(line[x * num: x * num + num])
#
# print_mxn("아이엠어보이유알어걸", 3)
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
def print_mxn(string,num):
  gul = int(len(string)/num)
  for x in range(gul+1):
    print(string[x*num:x*num+num])

print_mxn("아이엠어보이유알어걸", 3)
# Out:
# 아이엠
# 어보이
# 유알어
# 걸

# %% [markdown]
# ### 228 월급 계산 함수 (return)

# %% [markdown]
# 연봉을 입력받아 월급을 계산하는 calc_monthly_salary(annual_salary) 함수를 정의하라. 연봉을 12개월로 나누며 1원 미만은 버림한다.
# ```
# 실행 예:
# calc_monthly_salary(12000000)
# 1000000
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# return으로 계산 결과를 반환합니다. int()로 소수점 이하를 버림합니다.</br>
# <pre>
# def calc_monthly_salary(annual_pay):
#     monthly_pay = int(annual_pay / 12)
#     return monthly_pay
#
# result = calc_monthly_salary(12000000)
# print(result)
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
def calc_monthly_salary(annual_salary):
  return int(annual_salary/12)

calc_monthly_salary(12000000)
# Out:
# 1000000

# %% [markdown]
# ### 229 키워드 인자 - 결과 예측

# %% [markdown]
# 아래 코드의 실행 결과를 예측하라.
# ```python
# def my_print(a, b):
#     print("왼쪽:", a)
#     print("오른쪽:", b)
#
# my_print(a=100, b=200)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 키워드 인자(keyword argument)는 파라미터 이름을 명시해서 전달합니다. 순서와 상관없이 이름으로 바인딩됩니다.</br>
# <pre>
# # 결과:
# # 왼쪽: 100
# # 오른쪽: 200
# </pre>
# </details>

# %%
def my_print(a, b):
    print("왼쪽:", a)
    print("오른쪽:", b)

my_print(a=100, b=200)
# 왼쪽: 100
# 오른쪽: 200
# Out:
# 왼쪽: 100
# 오른쪽: 200

# %% [markdown]
# ### 230 키워드 인자 역순 - 결과 예측

# %% [markdown]
# 아래 코드의 실행 결과를 예측하라.
# ```python
# def my_print(a, b):
#     print("왼쪽:", a)
#     print("오른쪽:", b)
#
# my_print(b=100, a=200)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 키워드 인자는 순서가 바뀌어도 이름으로 바인딩되므로 a=200, b=100이 됩니다.</br>
# <pre>
# # 결과:
# # 왼쪽: 200
# # 오른쪽: 100
# </pre>
# </details>

# %%
def my_print(a, b):
    print("왼쪽:", a)
    print("오른쪽:", b)

my_print(b=100, a=200)
# 왼쪽: 200
# 오른쪽: 100
# Out:
# 왼쪽: 200
# 오른쪽: 100
