# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 01. 파이썬 시작하기

# %% [markdown]
# ### 001 print 기초

# %% [markdown]
# 화면에 `Hello World` 문자열을 출력하세요.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# print는 정수, 실수, 문자열 등을 화면에 출력합니다. 문자열은 큰따옴표 또는 작은따옴표로 표현 가능합니다.</br>
# <pre>
# print("Hello World")
# print('Hello World')
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### 002 print 기초

# %% [markdown]
# 화면에 `Mary's cosmetics`을 출력하세요. (중간에 '가 있음에 주의하세요)

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 문자열은 큰따옴표나 작은따옴표로 표현 가능합니다.</br>
# 표현하고 싶은 문자열에 작은따옴표가 있으므로 문자열을 큰따옴표로 만들어주면 됩니다.</br>
# <pre>
# print("Mary's cosmetics")
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %% [markdown]
# ### 003 print 기초

# %% [markdown]
# 화면에 아래 문장을 출력하세요. (중간에 "가 있음에 주의하세요.)</br>
# 신씨가 소리질렀다. "도둑이야".

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 표현하고 싶은 문자열에 큰따옴표가 포함되어 있습니다. 따라서 작은따옴표로 문자열을 만들어주면 됩니다.</br>
# <pre>
# print('신씨가 소리질렀다. "도둑이야"')
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
print('신씨가 소리질렀다. "도둑이야".')
# Out:
# 신씨가 소리질렀다. "도둑이야".

# %% [markdown]
# ### 004 print 기초

# %% [markdown]
# 화면에 `C:\Windows`를 출력하세요.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 운영체제(윈도우/리눅스/맥) 및 설정 폰트에 따라 역슬래시가 원화 표시로 표기될 수 있습니다. 모두 정답입니다.</br>
# <pre>
# print("C:\\Windows")
# </pre>
# 또는 raw string을 사용할 수도 있습니다.
# <pre>
# print(r"C:\Windows")
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
print("C\Windows")
# Out:
# C\Windows
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# /tmp/ipykernel_5742/3035338671.py:2: SyntaxWarning: invalid escape sequence '\W'
#   print("C\Windows")

# %% [markdown]
# ### 005 print 탭과 줄바꿈

# %% [markdown]
# 다음 코드를 실행해보고 `\t`와 `\n`의 역할을 설명해보세요.
# ```python
# print("안녕하세요.\n만나서\t\t반갑습니다.")
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>\n</code>은 줄바꿈(개행)을 의미합니다.</br>
# <code>\t</code>는 탭(Tab) 간격을 의미합니다. 키보드의 Tab 키를 누른 것과 같은 효과입니다.</br>
# <pre>
# # 출력 결과:
# # 안녕하세요.
# # 만나서		반갑습니다.
# print("안녕하세요.\n만나서\t\t반갑습니다.")
# </pre>
# </details>

# %%
# 직접 실행해서 결과를 확인해보세요
print("이제 줄 바꿈을 해볼게요 얍!\n이제 탭을 해볼게요 얍!\t 됬네요")
# Out:
# 이제 줄 바꿈을 해볼게요 얍!
# 이제 탭을 해볼게요 얍!	 됬네요

# %% [markdown]
# ### 006 print 여러 데이터 출력

# %% [markdown]
# print 함수에 두 개의 단어를 입력한 예제입니다. 아래 코드의 출력 결과를 예상해봅시다.
# ```python
# print("오늘은", "일요일")
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 여러 값을 출력하려면 print 함수에서 쉼표(,)로 구분해주면 됩니다.</br>
# 쉼표로 구분된 값들 사이에는 자동으로 공백 한 칸이 들어갑니다.</br>
# <pre>
# # 출력 결과: 오늘은 일요일
# print("오늘은", "일요일")
# </pre>
# </details>

# %%
# 직접 실행해서 결과를 확인해보세요
print("처음이야","두번째야")
# Out:
# 처음이야 두번째야

# %% [markdown]
# ### 007 print 기초

# %% [markdown]
# print() 함수를 사용하여 다음과 같이 출력하세요.
# ```
# naver;kakao;sk;samsung
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# print 함수의 <code>sep</code> 인자로 구분자를 직접 지정할 수 있습니다.</br>
# 기본값은 공백(" ")이지만, sep=";" 처럼 원하는 문자로 바꿀 수 있습니다.</br>
# <pre>
# print("naver", "kakao", "sk", "samsung", sep=";")
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
print("naver;kakao;sk;samsung")
#print("naver", "kakao", "sk", "samsung", sep=";") 이런 방법도 있음 sep로 구분자 가능
# Out:
# naver;kakao;sk;samsung

# %% [markdown]
# ### 008 print 기초

# %% [markdown]
# print() 함수를 사용하여 다음과 같이 출력하세요.
# ```
# naver/kakao/sk/samsung
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 007번과 동일하게 sep 인자를 사용합니다. 이번엔 구분자를 "/"로 지정합니다.</br>
# <pre>
# print("naver", "kakao", "sk", "samsung", sep="/")
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
print("naver","kakao","sk","samsung", sep="/")
# Out:
# naver/kakao/sk/samsung

# %% [markdown]
# ### 009 print 줄바꿈

# %% [markdown]
# 다음 코드를 수정하여 줄바꿈 없이 한 줄에 출력하세요. (힌트: `end=''`)</br>
# print 함수는 두 번 사용합니다.
# ```python
# print("first"); print("second")
# ```
# ```
# 실행 예:
# firstsecond
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# print 함수는 기본적으로 출력 후 줄바꿈을 합니다. <code>end=""</code>를 사용하면 줄바꿈 대신 빈 문자열로 끝나게 됩니다.</br>
# 세미콜론(;)은 한 줄에 여러 개의 명령을 작성할 때 사용합니다.</br>
# <pre>
# print("first", end=""); print("second")
# </pre>
# </details>

# %%
# 아래 코드를 수정해보세요
print("first"); print("second")
print("")
print("first", end=""); print("second")
# Out:
# first
# second
#
# firstsecond

# %% [markdown]
# ### 010 연산 결과 출력

# %% [markdown]
# 5/3의 결과를 화면에 출력하세요.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 출력하고 싶은 값을 print 함수의 인자로 적어주면 됩니다.</br>
# 파이썬 3에서 /는 항상 나눗셈(실수 결과)을 반환합니다.</br>
# <pre>
# print(5/3)  # 1.6666666666666667
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
print(5/3)
# Out:
# 1.6666666666666667
