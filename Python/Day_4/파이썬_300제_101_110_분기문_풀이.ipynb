# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 07. 파이썬 분기문 (101 ~ 110)

# %% [markdown]
# ### 101 bool 타입

# %% [markdown]
# 파이썬에서 True 혹은 False를 갖는 데이터 타입은 무엇인가?

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# bool 타입은 참(True)과 거짓(False) 두 가지 값만 가지는 데이터 타입입니다.</br>
# <pre>
# print(type(True))  # &lt;class 'bool'&gt;
# </pre>
# </details>

# %%
print(type(True))
# bool
# Out:
# <class 'bool'>

# %% [markdown]
# ### 102 비교 연산자

# %% [markdown]
# 아래 코드의 출력 결과를 예상하라.
# ```python
# print(3 == 5)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# == 는 두 값이 같은지 비교합니다. 3과 5는 다르므로 False가 출력됩니다.</br>
# <pre>
# print(3 == 5)  # False
# </pre>
# </details>

# %%
print(3 == 5)
# False
# Out:
# False

# %% [markdown]
# ### 103 비교 연산자

# %% [markdown]
# 아래 코드의 출력 결과를 예상하라.
# ```python
# print(3 < 5)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 3은 5보다 작으므로 True가 출력됩니다.</br>
# <pre>
# print(3 < 5)  # True
# </pre>
# </details>

# %%
print(3 < 5)
# True
# Out:
# True

# %% [markdown]
# ### 104 연속 비교

# %% [markdown]
# 아래 코드의 결과를 예상하라.
# ```python
# x = 4
# print(1 < x < 5)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 파이썬은 1 < 4 < 5 처럼 연속 비교를 지원합니다. 둘 다 참이므로 True입니다.</br>
# <pre>
# x = 4
# print(1 < x < 5)  # True
# </pre>
# </details>

# %%
x = 4
print(1 < x < 5)
# True
# Out:
# True

# %% [markdown]
# ### 105 논리 연산자 and

# %% [markdown]
# 아래 코드의 결과를 예상하라.
# ```python
# print((3 == 3) and (4 != 3))
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# and는 두 조건이 모두 참일 때 True를 반환합니다. 둘 다 참이므로 True입니다.</br>
# <pre>
# print((3 == 3) and (4 != 3))  # True
# </pre>
# </details>

# %%
print((3 == 3) and (4 != 3))
# True
# Out:
# True

# %% [markdown]
# ### 106 잘못된 연산자

# %% [markdown]
# 아래 코드에서 에러가 발생하는 원인을 설명하라.
# ```python
# print(3 => 4)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# => 는 파이썬에서 지원하지 않는 연산자입니다. 크거나 같다는 >= 로 써야 합니다.</br>
# <pre>
# # 올바른 코드:
# print(3 >= 4)  # False
# </pre>
# </details>

# %%
# => 대신 >= 를 사용하세요
print(3 >= 4)
# False

print(3 => 4)
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?
# Out:
#   File "/tmp/ipykernel_2062/2817348404.py", line 5
#     print(3 => 4)
#           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %% [markdown]
# ### 107 if문 기초

# %% [markdown]
# 아래 코드의 출력 결과를 예상하라.
# ```python
# if 4 < 3:
#     print('Hello World')
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 4 < 3은 False이므로 if 블록이 실행되지 않아 아무것도 출력되지 않습니다.</br>
# <pre>
# if 4 < 3:
#     print('Hello World')
# # 결과: 아무것도 출력되지 않음
# </pre>
# </details>

# %%
if 4 < 3:
    print('Hello World')
# False여서 아무것도 행동하지 않음

# %% [markdown]
# ### 108 if-else문

# %% [markdown]
# 아래 코드의 출력 결과를 예상하라.
# ```python
# if 4 < 3:
#     print('Hello World.')
# else:
#     print('Hi, there.')
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 4 < 3이 False이므로 else 블록이 실행됩니다.</br>
# <pre>
# # 결과: Hi, there.
# if 4 < 3:
#     print('Hello World.')
# else:
#     print('Hi, there.')
# </pre>
# </details>

# %%
if 4 < 3:
    print('Hello World.')
else:
    print('Hi, there.')
# Hi, there.
# Out:
# Hi, there.

# %% [markdown]
# ### 109 if문 들여쓰기

# %% [markdown]
# 아래 코드의 출력 결과를 예상하라.
# ```python
# if True:
#     print('1')
#     print('2')
# else:
#     print('3')
# print('4')
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 조건이 True이므로 if 블록(1, 2)이 실행됩니다. 4는 if문 밖이므로 항상 출력됩니다.</br>
# <pre>
# # 결과:
# # 1
# # 2
# # 4
# </pre>
# </details>

# %%
if True:
    print('1')
    print('2')
else:
    print('3')
print('4')

# 1
# 2
# 4
# Out:
# 1
# 2
# 4

# %% [markdown]
# ### 110 중첩 if문

# %% [markdown]
# 아래 코드의 출력 결과를 예상하라.
# ```python
# if True:
#     if False:
#         print('1')
#         print('2')
#     else:
#         print('3')
# else:
#     print('4')
# print('5')
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 바깥 if가 True, 안쪽 if가 False이므로 안쪽 else(3)가 실행됩니다. 5는 항상 출력됩니다.</br>
# <pre>
# # 결과:
# # 3
# # 5
# </pre>
# </details>

# %%
if True:
    if False:
        print('1')
        print('2')
    else:
        print('3')
else:
    print('4')
print('5')


# 3
# 5
# Out:
# 3
# 5
