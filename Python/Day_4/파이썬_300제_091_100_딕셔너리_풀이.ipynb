# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 06. 파이썬 딕셔너리 (091 ~ 100)

# %% [markdown]
# ### 091 딕셔너리 값으로 리스트 사용

# %% [markdown]
# 아래 표에서 아이스크림 이름을 키, (가격, 재고) 리스트를 값으로 하는 inventory 딕셔너리를 만드세요.
#
# | 이름 | 가격 | 재고 |
# | --- | --- | --- |
# | 메로나 | 300 | 20 |
# | 비비빅 | 400 | 3 |
# | 죠스바 | 250 | 100 |

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 딕셔너리의 값으로 리스트를 사용할 수 있습니다.</br>
# <pre>
# inventory = {"메로나": [300, 20], "비비빅": [400, 3], "죠스바": [250, 100]}
# print(inventory)
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
inventory = {"메로나":[300,20],"비비빅":[400,3],"죠스바":[250,100]}
print(inventory)
# Out:
# {'메로나': [300, 20], '비비빅': [400, 3], '죠스바': [250, 100]}

# %% [markdown]
# ### 092 중첩 딕셔너리 값 조회

# %% [markdown]
# inventory 딕셔너리에서 메로나의 가격을 출력하세요.
# ```python
# inventory = {"메로나": [300, 20], "비비빅": [400, 3], "죠스바": [250, 100]}
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 값이 리스트인 경우 <code>딕셔너리[키][인덱스]</code>로 접근합니다.</br>
# <pre>
# inventory = {"메로나": [300, 20], "비비빅": [400, 3], "죠스바": [250, 100]}
# print(inventory["메로나"][0])  # 300 (첫 번째 원소 = 가격)
# </pre>
# </details>

# %%
inventory = {"메로나": [300, 20], "비비빅": [400, 3], "죠스바": [250, 100]}
# 여기에 코드를 작성하세요
print(inventory["메로나"][0])
# Out:
# 300

# %% [markdown]
# ### 093 딕셔너리 항목 추가

# %% [markdown]
# inventory에 월드콘(가격: 500, 재고: 7)을 추가하세요.
# ```python
# inventory = {"메로나": [300, 20], "비비빅": [400, 3], "죠스바": [250, 100]}
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# inventory = {"메로나": [300, 20], "비비빅": [400, 3], "죠스바": [250, 100]}
# inventory["월드콘"] = [500, 7]
# print(inventory)
# </pre>
# </details>

# %%
inventory = {"메로나": [300, 20], "비비빅": [400, 3], "죠스바": [250, 100]}
# 여기에 코드를 작성하세요
inventory["월드콘"] = [500,7]
print(inventory)
# Out:
# {'메로나': [300, 20], '비비빅': [400, 3], '죠스바': [250, 100], '월드콘': [500, 7]}

# %% [markdown]
# ### 094 딕셔너리 키 목록

# %% [markdown]
# 딕셔너리의 키 값으로만 구성된 리스트를 생성하세요.
# ```python
# icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>keys()</code> 메서드로 키만 추출하고 <code>list()</code>로 변환합니다.</br>
# <pre>
# icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
# name = list(icecream.keys())
# print(name)
# </pre>
# </details>

# %%
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
# 여기에 코드를 작성하세요
print(list(icecream.keys()))
# Out:
# ['탱크보이', '폴라포', '빵빠레', '월드콘', '메로나']

# %% [markdown]
# ### 095 딕셔너리 값 목록

# %% [markdown]
# 딕셔너리의 값으로만 구성된 리스트를 생성하세요.
# ```python
# icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>values()</code> 메서드로 값만 추출하고 <code>list()</code>로 변환합니다.</br>
# <pre>
# icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
# price = list(icecream.values())
# print(price)
# </pre>
# </details>

# %%
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
# 여기에 코드를 작성하세요
print(list(icecream.values()))
# Out:
# [1200, 1200, 1800, 1500, 1000]

# %% [markdown]
# ### 096 딕셔너리 값 합계

# %% [markdown]
# icecream 딕셔너리에서 아이스크림 판매 금액의 총합을 출력하세요.
# ```python
# icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>sum(딕셔너리.values())</code>로 값들의 합을 구합니다.</br>
# <pre>
# icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
# print(sum(icecream.values()))
# </pre>
# </details>

# %%
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
# 여기에 코드를 작성하세요
print(sum(icecream.values()))
# Out:
# 6700

# %% [markdown]
# ### 097 딕셔너리 합치기 (update)

# %% [markdown]
# new_product 딕셔너리를 icecream 딕셔너리에 추가하세요.
# ```python
# icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
# new_product = {'팥빙수': 2700, '아맛나': 1000}
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>update()</code> 메서드로 딕셔너리를 합칩니다.</br>
# <pre>
# icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
# new_product = {'팥빙수': 2700, '아맛나': 1000}
# icecream.update(new_product)
# print(icecream)
# </pre>
# </details>

# %%
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
new_product = {'팥빙수': 2700, '아맛나': 1000}
# 여기에 코드를 작성하세요
icecream.update(new_product)
print(icecream)
# Out:
# {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000, '팥빙수': 2700, '아맛나': 1000}

# %% [markdown]
# ### 098 zip으로 딕셔너리 생성

# %% [markdown]
# 두 개의 튜플을 하나의 딕셔너리로 변환하세요.
# ```python
# keys = ("apple", "pear", "peach")
# vals = (300, 250, 400)
# ```
# ```
# 실행 예시:
# {'apple': 300, 'pear': 250, 'peach': 400}
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>zip()</code>으로 두 시퀀스를 묶고, <code>dict()</code>로 딕셔너리를 생성합니다.</br>
# <pre>
# keys = ("apple", "pear", "peach")
# vals = (300, 250, 400)
# result = dict(zip(keys, vals))
# print(result)
# </pre>
# </details>

# %%
keys = ("apple", "pear", "peach")
vals = (300, 250, 400)
num = (5,1,3)
# 여기에 코드를 작성하세요
fruits = dict(zip(keys,vals))
print(fruits)

# fruits = dict(zip(keys,vals,num)) << 불가능    # ValueError: dictionary update sequence element #0 has length 3; 2 is required
# Out:
# {'apple': 300, 'pear': 250, 'peach': 400}

# %% [markdown]
# ### 099 zip으로 딕셔너리 생성 (2)

# %% [markdown]
# date와 close_price 두 리스트를 close_table 이름의 딕셔너리로 생성하세요.
# ```python
# date = ['09/05', '09/06', '09/07', '09/08', '09/09']
# close_price = [10500, 10300, 10100, 10800, 11000]
# ```
# ```
# 실행 예시:
# {'09/05': 10500, '09/06': 10300, '09/07': 10100, '09/08': 10800, '09/09': 11000}
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# date = ['09/05', '09/06', '09/07', '09/08', '09/09']
# close_price = [10500, 10300, 10100, 10800, 11000]
# close_table = dict(zip(date, close_price))
# print(close_table)
# </pre>
# </details>

# %%
date = ['09/05', '09/06', '09/07', '09/08', '09/09']
close_price = [10500, 10300, 10100, 10800, 11000]
# 여기에 코드를 작성하세요
datalist = dict(zip(date,close_price))
print(datalist)
# Out:
# {'09/05': 10500, '09/06': 10300, '09/07': 10100, '09/08': 10800, '09/09': 11000}

# %% [markdown]
# ### 100 딕셔너리 in 연산자

# %% [markdown]
# '메로나'가 icecream 딕셔너리에 존재하는지 확인하세요.
# ```python
# icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>in</code> 연산자는 딕셔너리에서 키의 존재 여부를 True/False로 반환합니다.</br>
# <pre>
# icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
# print('메로나' in icecream)   # True
# print('누가바' in icecream)   # False
# </pre>
# </details>

# %%
from re import I
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
# 여기에 코드를 작성하세요
print("바밤바" in icecream)
print("탱크보이"in icecream)
# Out:
# False
# True
