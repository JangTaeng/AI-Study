# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 07. 파이썬 분기문 (111 ~ 120)

# %% [markdown]
# ### 111 input + 문자열 반복

# %% [markdown]
# 사용자로부터 입력받은 문자열을 두 번 출력하라.
# ```
# 실행 예:
# >> 안녕하세요
# 안녕하세요안녕하세요
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# input() 함수로 사용자 입력을 받고, 문자열 * 2 로 두 번 반복합니다.</br>
# <pre>
# user = input("입력:")
# print(user * 2)
# </pre>
# </details>

# %%
user = input("입력:")
# 여기에 코드를 작성하세요
print(user*2)
# Out:
# 입력:aa
# aaaa

# %% [markdown]
# ### 112 input + 덧셈

# %% [markdown]
# 사용자로부터 하나의 숫자를 입력받고, 입력 받은 숫자에 10을 더해 출력하라.
# ```
# 실행 예:
# >> 숫자를 입력하세요: 30
# 40
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# input()은 항상 문자열로 받으므로, int()로 변환 후 연산해야 합니다.</br>
# <pre>
# user = input("숫자를 입력하세요: ")
# print(10 + int(user))
# </pre>
# </details>

# %%
user = input("숫자를 입력하세요: ")
# 여기에 코드를 작성하세요
print(int(user)+10)
# Out:
# 숫자를 입력하세요: 80
# 90

# %% [markdown]
# ### 113 짝수/홀수 판별

# %% [markdown]
# 사용자로부터 하나의 숫자를 입력 받고 짝수/홀수를 판별하라.
# ```
# 실행 예:
# >> 30
# 짝수
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 2로 나눈 나머지(%)가 0이면 짝수, 아니면 홀수입니다.</br>
# <pre>
# user = input("")
# if int(user) % 2 == 0:
#     print("짝수")
# else:
#     print("홀수")
# </pre>
# </details>

# %%
user = input("숫자를 입력하세요: ")
# 여기에 코드를 작성하세요
if int(user) % 2 == 0:
    print("짝수")
else:
    print("홀수")
# Out:
# 숫자를 입력하세요: 70
# 짝수

# %% [markdown]
# ### 114 값 범위 제한 (상한)

# %% [markdown]
# 사용자로부터 값을 입력받은 후 해당 값에 20을 더한 값을 출력하라. 단 결괏값이 255를 초과하는 경우 255를 출력해야 한다.
# ```
# 실행 예1:
# >> 입력값: 200
# 출력값: 220
#
# 실행 예2:
# >> 입력값: 240
# 출력값: 255
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 계산 결과가 255보다 크면 255를, 아니면 계산 결과를 출력합니다.</br>
# <pre>
# user = input("입력값: ")
# num = 20 + int(user)
# if num > 255:
#     print(255)
# else:
#     print(num)
# </pre>
# </details>

# %%
user = input("입력값: ")
# 여기에 코드를 작성하세요
num = int(user)+20
if num > 255:
    print(255)
else:
    print(num)
# Out:
# 입력값: 15
# 35

# %% [markdown]
# ### 115 값 범위 제한 (0~255)

# %% [markdown]
# 사용자로부터 하나의 값을 입력받은 후 해당 값에 20을 뺀 값을 출력하라. 단 출력 값의 범위는 0~255이다.
# ```
# 실행 예1:
# >> 입력값: 200
# 출력값: 180
#
# 실행 예2:
# >> 입력값: 15
# 출력값: 0
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# elif를 사용해 세 가지 경우를 처리합니다.</br>
# <pre>
# user = input("입력값: ")
# num = int(user) - 20
# if num > 255:
#     print(255)
# elif num < 0:
#     print(0)
# else:
#     print(num)
# </pre>
# </details>

# %%
user = input("입력값: ")
# 여기에 코드를 작성하세요
num = int(user)-20
if num > 255:
    print(255)
elif num < 0:
    print(0)
else:
    print(num)
# Out:
# 입력값: 245
# 225

# %% [markdown]
# ### 116 정각 판별

# %% [markdown]
# 사용자로부터 입력 받은 시간이 정각인지 판별하라.
# ```
# 실행 예1:
# >> 현재시간: 02:00
# 정각 입니다.
#
# 실행 예2:
# >> 현재시간: 03:10
# 정각이 아닙니다.
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 슬라이싱으로 마지막 2자리(분)를 확인합니다.</br>
# <pre>
# time = input("현재시간: ")
# if time[-2:] == "00":
#     print("정각 입니다.")
# else:
#     print("정각이 아닙니다.")
# </pre>
# </details>

# %%
time = input("현재시간: ")
# 여기에 코드를 작성하세요
clock = time[-2:]
print(clock)
if clock == "00":
    print("정각 입니다.")
else:
    print("정각이 아닙니다.")
# Out:
# 현재시간: 12:31
# 31
# 정각이 아닙니다.

# %% [markdown]
# ### 117 리스트 in 연산자

# %% [markdown]
# 사용자로 입력받은 단어가 fruit 리스트에 포함되어 있는지 확인하라.
# ```python
# fruit = ["사과", "포도", "홍시"]
# ```
# ```
# 실행 예:
# >> 좋아하는 과일은? 사과
# 정답입니다.
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>in</code> 연산자는 리스트에 해당 값이 있는지 확인합니다.</br>
# <pre>
# fruit = ["사과", "포도", "홍시"]
# user = input("좋아하는 과일은?")
# if user in fruit:
#     print("정답입니다.")
# else:
#     print("오답입니다.")
# </pre>
# </details>

# %%
fruit = ["사과", "포도", "홍시"]
user = input("좋아하는 과일은? ")
# 여기에 코드를 작성하세요
if user in fruit:
    print("정답입니다.")
else:
    print("오답입니다.")
# Out:
# 좋아하는 과일은? d
# 오답입니다.

# %% [markdown]
# ### 118 투자 경고 종목 조회

# %% [markdown]
# 투자 경고 종목 리스트가 있을 때 사용자로부터 종목명을 입력 받은 후 해당 종목이 투자 경고 종목인지 출력하는 프로그램을 작성하라.
# ```python
# warn_investment_list = ["Microsoft", "Google", "Naver", "Kakao", "SAMSUNG", "LG"]
# ```
# ```
# 실행 예:
# >> 종목명: Naver
# 투자 경고 종목입니다.
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# warn_investment_list = ["Microsoft", "Google", "Naver", "Kakao", "SAMSUNG", "LG"]
# 종목 = input("종목명: ")
# if 종목 in warn_investment_list:
#     print("투자 경고 종목입니다.")
# else:
#     print("투자 경고 종목이 아닙니다.")
# </pre>
# </details>

# %%
warn_investment_list = ["Microsoft", "Google", "Naver", "Kakao", "SAMSUNG", "LG"]
종목 = input("종목명: ")
# 여기에 코드를 작성하세요
if 종목 in warn_investment_list:
    print("투자 경고 종목입니다.")
else:
    print("투자 경고 종목이 아닙니다.")
# Out:
# 종목명: Naver
# 투자 경고 종목입니다.

# %% [markdown]
# ### 119 딕셔너리 key 포함 여부

# %% [markdown]
# 아래와 같이 fruit 딕셔너리가 정의되어 있다. 사용자가 입력한 값이 딕셔너리 키(key)에 포함되었다면 '정답입니다'를 아닐 경우 '오답입니다'를 출력하라.
# ```python
# fruit = {"봄": "딸기", "여름": "토마토", "가을": "사과"}
# ```
# ```
# 실행 예:
# >> 제가좋아하는계절은: 봄
# 정답입니다.
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 딕셔너리에서 <code>in</code> 연산자는 기본적으로 키(key)를 검색합니다.</br>
# <pre>
# fruit = {"봄": "딸기", "여름": "토마토", "가을": "사과"}
# user = input("제가좋아하는계절은: ")
# if user in fruit:
#     print("정답입니다.")
# else:
#     print("오답입니다.")
# </pre>
# </details>

# %%
fruit = {"봄": "딸기", "여름": "토마토", "가을": "사과"}
user = input("제가좋아하는계절은: ")
# 여기에 코드를 작성하세요
if user in fruit:
    print("정답입니다.")
else:
    print("오답입니다.")
# Out:
# 제가좋아하는계절은: 여름
# 정답입니다.

# %% [markdown]
# ### 120 딕셔너리 value 포함 여부

# %% [markdown]
# 아래와 같이 fruit 딕셔너리가 정의되어 있다. 사용자가 입력한 값이 딕셔너리 값(value)에 포함되었다면 '정답입니다'를 아닐 경우 '오답입니다'를 출력하라.
# ```python
# fruit = {"봄": "딸기", "여름": "토마토", "가을": "사과"}
# ```
# ```
# 실행 예:
# >> 좋아하는과일은? 한라봉
# 오답입니다.
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 값(value)을 검색할 때는 <code>딕셔너리.values()</code>를 사용합니다.</br>
# <pre>
# fruit = {"봄": "딸기", "여름": "토마토", "가을": "사과"}
# user = input("좋아하는 과일은?")
# if user in fruit.values():
#     print("정답입니다.")
# else:
#     print("오답입니다.")
# </pre>
# </details>

# %%
fruit = {"봄": "딸기", "여름": "토마토", "가을": "사과"}
user = input("좋아하는 과일은? ")
# 여기에 코드를 작성하세요
if user in fruit.values():
  print("정답입니다.")
else:
  print("오답입니다.")
# Out:
# 좋아하는 과일은? 봄
# 오답입니다.
