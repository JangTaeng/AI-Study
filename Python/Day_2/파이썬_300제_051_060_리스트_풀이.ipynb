# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 04. 파이썬 리스트 (051 ~ 060)

# %% [markdown]
# ### 051 리스트 생성

# %% [markdown]
# 2016년 11월 영화 예매 순위 기준 top3입니다. 영화 제목을 movie_rank 이름의 리스트에 저장해보세요. (순위는 저장하지 않습니다.)
#
# | 순위 | 영화 |
# | --- | --- |
# | 1 | 닥터 스트레인지 |
# | 2 | 스플릿 |
# | 3 | 럭키 |

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 리스트는 대괄호 []를 사용하며, 여러 값을 쉼표로 구분합니다.</br>
# <pre>
# movie_rank = ["닥터 스트레인지", "스플릿", "럭키"]
# print(movie_rank)
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
movie_rank = ["닥터 스트레인지","스플릿","럭키"]
print(movie_rank)
# Out:
# ['닥터 스트레인지', '스플릿', '럭키']

# %% [markdown]
# ### 052 리스트에 원소 추가

# %% [markdown]
# 051의 movie_rank 리스트에 "배트맨"을 추가하세요.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>append()</code> 메서드는 리스트의 맨 끝에 원소를 추가합니다.</br>
# <pre>
# movie_rank = ["닥터 스트레인지", "스플릿", "럭키"]
# movie_rank.append("배트맨")
# print(movie_rank)
# </pre>
# </details>

# %%
movie_rank = ["닥터 스트레인지", "스플릿", "럭키"]
# 여기에 코드를 작성하세요
movie_rank.append("배트맨")
print(movie_rank)
# Out:
# ['닥터 스트레인지', '스플릿', '럭키', '배트맨']

# %% [markdown]
# ### 053 리스트 중간에 삽입

# %% [markdown]
# "슈퍼맨"을 "닥터 스트레인지"와 "스플릿" 사이에 추가하세요.
# ```python
# movie_rank = ['닥터 스트레인지', '스플릿', '럭키', '배트맨']
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>insert(인덱스, 값)</code>은 특정 위치에 원소를 끼워 넣습니다. 인덱스 1은 두 번째 자리입니다.</br>
# <pre>
# movie_rank = ['닥터 스트레인지', '스플릿', '럭키', '배트맨']
# movie_rank.insert(1, "슈퍼맨")
# print(movie_rank)
# </pre>
# </details>

# %%
movie_rank = ['닥터 스트레인지', '스플릿', '럭키', '배트맨']
# 여기에 코드를 작성하세요
movie_rank.insert(1,"슈퍼맨")
print(movie_rank)
# Out:
# ['닥터 스트레인지', '슈퍼맨', '스플릿', '럭키', '배트맨']

# %% [markdown]
# ### 054 리스트 원소 삭제

# %% [markdown]
# movie_rank에서 '럭키'를 삭제하세요.
# ```python
# movie_rank = ['닥터 스트레인지', '슈퍼맨', '스플릿', '럭키', '배트맨']
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>del 리스트[인덱스]</code>로 특정 위치의 원소를 삭제합니다. '럭키'는 인덱스 3입니다.</br>
# <pre>
# movie_rank = ['닥터 스트레인지', '슈퍼맨', '스플릿', '럭키', '배트맨']
# del movie_rank[3]
# print(movie_rank)
# </pre>
# </details>

# %%
movie_rank = ['닥터 스트레인지', '슈퍼맨', '스플릿', '럭키', '배트맨']
# 여기에 코드를 작성하세요
movie_rank.remove("럭키")
print(movie_rank)
# Out:
# ['닥터 스트레인지', '슈퍼맨', '스플릿', '배트맨']

# %% [markdown]
# ### 055 리스트 원소 여러 개 삭제

# %% [markdown]
# movie_rank에서 '스플릿'과 '배트맨'을 삭제하세요.
# ```python
# movie_rank = ['닥터 스트레인지', '슈퍼맨', '스플릿', '배트맨']
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 원소를 하나 삭제하면 인덱스가 재정렬됩니다. 순서에 주의해서 삭제합니다.</br>
# <pre>
# movie_rank = ['닥터 스트레인지', '슈퍼맨', '스플릿', '배트맨']
# del movie_rank[2]  # '스플릿' 삭제
# del movie_rank[2]  # 삭제 후 '배트맨'이 인덱스 2로 이동
# print(movie_rank)
# </pre>
# </details>

# %%
movie_rank = ['닥터 스트레인지', '슈퍼맨', '스플릿', '배트맨']
# 여기에 코드를 작성하세요
movie_rank.remove("스플릿")
movie_rank.remove("배트맨")
print(movie_rank)
# Out:
# ['닥터 스트레인지', '슈퍼맨']

# %% [markdown]
# ### 056 리스트 합치기

# %% [markdown]
# lang1과 lang2의 원소를 모두 갖는 langs 리스트를 만드세요.
# ```python
# lang1 = ["C", "C++", "JAVA"]
# lang2 = ["Python", "Go", "C#"]
# ```
# ```
# 실행 예:
# ['C', 'C++', 'JAVA', 'Python', 'Go', 'C#']
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 두 리스트를 <code>+</code>로 더하면 하나의 새 리스트가 생성됩니다.</br>
# <pre>
# lang1 = ["C", "C++", "JAVA"]
# lang2 = ["Python", "Go", "C#"]
# langs = lang1 + lang2
# print(langs)
# </pre>
# </details>

# %%
lang1 = ["C", "C++", "JAVA"]
lang2 = ["Python", "Go", "C#"]
# 여기에 코드를 작성하세요
lang1.extend(lang2)
print(lang1)
# Out:
# ['C', 'C++', 'JAVA', 'Python', 'Go', 'C#']

# %% [markdown]
# ### 057 최댓값 최솟값

# %% [markdown]
# 리스트의 최댓값과 최솟값을 출력하세요.
# ```python
# nums = [1, 2, 3, 4, 5, 6, 7]
# ```
# ```
# 실행 예:
# max:  7
# min:  1
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>max()</code>와 <code>min()</code> 내장함수를 사용합니다.</br>
# <pre>
# nums = [1, 2, 3, 4, 5, 6, 7]
# print("max: ", max(nums))
# print("min: ", min(nums))
# </pre>
# </details>

# %%
nums = [1, 2, 3, 4, 5, 6, 7]
# 여기에 코드를 작성하세요
print("max: ", max(nums))
print("min: ", min(nums))
# Out:
# max:  7
# min:  1

# %% [markdown]
# ### 058 리스트 합계

# %% [markdown]
# 리스트의 합을 출력하세요.
# ```python
# nums = [1, 2, 3, 4, 5]
# ```
# ```
# 실행 예: 15
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>sum()</code> 내장함수는 리스트 원소의 합계를 반환합니다.</br>
# <pre>
# nums = [1, 2, 3, 4, 5]
# print(sum(nums))
# </pre>
# </details>

# %%
nums = [1, 2, 3, 4, 5]
# 여기에 코드를 작성하세요
print(sum(nums))
# Out:
# 15

# %% [markdown]
# ### 059 리스트 길이

# %% [markdown]
# 리스트에 저장된 데이터의 개수를 출력하세요.
# ```python
# cook = ["피자", "김밥", "만두", "양념치킨", "족발", "피자", "김치만두", "쫄면", "소시지", "라면", "팥빙수", "김치전"]
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>len()</code> 함수는 리스트(또는 문자열 등)의 길이를 반환합니다.</br>
# <pre>
# cook = ["피자", "김밥", "만두", "양념치킨", "족발", "피자", "김치만두", "쫄면", "소시지", "라면", "팥빙수", "김치전"]
# print(len(cook))
# </pre>
# </details>

# %%
cook = ["피자", "김밥", "만두", "양념치킨", "족발", "피자", "김치만두", "쫄면", "소시지", "라면", "팥빙수", "김치전"]
# 여기에 코드를 작성하세요
print(len(cook))
# Out:
# 12

# %% [markdown]
# ### 060 리스트 평균

# %% [markdown]
# 리스트의 평균을 출력하세요.
# ```python
# nums = [1, 2, 3, 4, 5]
# ```
# ```
# 실행 예: 3.0
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 평균 = 합계 / 개수. <code>sum()</code>과 <code>len()</code>을 활용합니다.</br>
# <pre>
# nums = [1, 2, 3, 4, 5]
# average = sum(nums) / len(nums)
# print(average)
# </pre>
# </details>

# %%
nums = [1, 2, 3, 4, 5]
# 여기에 코드를 작성하세요
print(sum(nums)/len(nums))
# Out:
# 3.0
