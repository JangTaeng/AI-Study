# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 03. 파이썬 문자열 (031 ~ 040)

# %% [markdown]
# ### 031 문자열 합치기

# %% [markdown]
# 아래 코드의 실행 결과를 예상해보세요.
# ```python
# a = "3"
# b = "4"
# print(a + b)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 두 문자열에 대해 덧셈 기호(+)는 문자열의 연결을 의미합니다. 숫자 3+4=7이 아니라 문자열 "3"과 "4"가 이어붙어 "34"가 출력됩니다.</br>
# <pre>
# a = "3"
# b = "4"
# print(a + b)  # 결과: 34
# </pre>
# </details>

# %%
# 직접 실행해서 결과를 확인해보세요
a = "3"
b = "4"
print(a + b)  #34
# Out:
# 34

# %% [markdown]
# ### 032 문자열 곱하기

# %% [markdown]
# 아래 코드의 실행 결과를 예상해보세요.
# ```python
# print("Hi" * 3)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 문자열에 대한 곱셈(*)은 문자열의 반복을 의미합니다.</br>
# <pre>
# print("Hi" * 3)  # 결과: HiHiHi
# </pre>
# </details>

# %%
# 직접 실행해서 결과를 확인해보세요
print("Hi" * 3) #HiHiHi
# Out:
# HiHiHi

# %% [markdown]
# ### 033 문자열 곱하기

# %% [markdown]
# 화면에 '-'를 80개 출력하세요.
# ```
# 실행 예:
# --------------------------------------------------------------------------------
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 문자열 곱하기를 사용하면 간단히 반복 출력할 수 있습니다.</br>
# <pre>
# print("-" * 80)
# </pre>
# </details>

# %%
# 여기에 코드를 작성하세요
print("-"*80)
# Out:
# --------------------------------------------------------------------------------

# %% [markdown]
# ### 034 문자열 곱하기

# %% [markdown]
# 변수에 다음과 같은 문자열이 바인딩되어 있습니다.
# ```python
# t1 = 'python'
# t2 = 'java'
# ```
# 변수에 문자열 더하기와 문자열 곱하기를 사용해서 아래와 같이 출력해보세요.
# ```
# 실행 예:
# python java python java python java python java
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 두 문자열을 더한 후 4번 반복합니다.</br>
# <pre>
# t1 = "python"
# t2 = "java"
# t3 = t1 + ' ' + t2 + ' '
# print(t3 * 4)
# </pre>
# </details>

# %%
t1 = 'python'
t2 = 'java'
# 여기에 코드를 작성하세요
t3 = t1 + ' ' + t2 + ' '
print(t3 * 4)
# Out:
# python java python java python java python java

# %% [markdown]
# ### 035 문자열 출력 (% formatting)

# %% [markdown]
# 변수에 다음과 같이 문자열과 정수가 바인딩되어 있을 때 `% formatting`을 사용해서 출력해보세요.
# ```python
# name1 = "김민수"
# age1 = 10
# name2 = "이철희"
# age2 = 13
# ```
# ```
# 실행 예:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>%s</code>는 문자열, <code>%d</code>는 정수 타입의 값을 출력합니다.</br>
# <pre>
# name1 = "김민수"
# age1 = 10
# name2 = "이철희"
# age2 = 13
# print("이름: %s 나이: %d" % (name1, age1))
# print("이름: %s 나이: %d" % (name2, age2))
# </pre>
# </details>

# %%
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13
# 여기에 코드를 작성하세요
print("이름: %s 나이: %d"%(name1,age1))
print("이름: %s 나이: %d"%(name2,age2))
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %% [markdown]
# ### 036 문자열 출력 (format 메서드)

# %% [markdown]
# 문자열의 `format()` 메서드를 사용해서 035번 문제를 다시 풀어보세요.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# format 메서드는 타입과 상관없이 값이 출력될 위치에 <code>{}</code>를 사용합니다.</br>
# <pre>
# name1 = "김민수"
# age1 = 10
# name2 = "이철희"
# age2 = 13
# print("이름: {} 나이: {}".format(name1, age1))
# print("이름: {} 나이: {}".format(name2, age2))
# </pre>
# </details>

# %%
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13
# 여기에 코드를 작성하세요
print("이름: {} 나이: {}".format(name1, age1))
print("이름: {} 나이: {}".format(name2, age2))
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %% [markdown]
# ### 037 문자열 출력 (f-string)

# %% [markdown]
# 파이썬 3.6부터 지원하는 f-string을 사용해서 035번 문제를 다시 풀어보세요.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# f-string은 문자열 앞에 <code>f</code>를 붙이고, <code>{변수}</code> 형태로 값을 바로 넣을 수 있어 가장 간결합니다.</br>
# <pre>
# name1 = "김민수"
# age1 = 10
# name2 = "이철희"
# age2 = 13
# print(f"이름: {name1} 나이: {age1}")
# print(f"이름: {name2} 나이: {age2}")
# </pre>
# </details>

# %%
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13
# 여기에 코드를 작성하세요
print(f"이름: {name1} 나이: {age1}")
print(f"이름: {name2} 나이: {age2}")
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %% [markdown]
# ### 038 컴마 제거하기

# %% [markdown]
# 삼성전자의 상장주식수가 다음과 같습니다. 컴마를 제거한 후 정수 타입으로 변환해보세요.
# ```python
# 상장주식수 = "5,969,782,550"
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 컴마가 포함된 문자열은 int()로 바로 변환되지 않습니다. replace로 먼저 컴마를 제거한 후 변환해야 합니다.</br>
# <pre>
# 상장주식수 = "5,969,782,550"
# 컴마제거 = 상장주식수.replace(",", "")
# 타입변환 = int(컴마제거)
# print(타입변환, type(타입변환))
# </pre>
# </details>

# %%
from os import replace
상장주식수 = "5,969,782,550"
# 여기에 코드를 작성하세요
d = 상장주식수.replace(",","")
i = int(d)
print(i)
# Out:
# 5969782550

# %% [markdown]
# ### 039 문자열 슬라이싱

# %% [markdown]
# 다음과 같은 문자열에서 '2020/03'만 출력하세요.
# ```python
# 분기 = "2020/03(E) (IFRS연결)"
# ```
# ```
# 실행 예:
# 2020/03
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 슬라이싱으로 앞에서 7번째 문자까지만 가져옵니다.</br>
# <pre>
# 분기 = "2020/03(E) (IFRS연결)"
# print(분기[:7])
# </pre>
# </details>

# %%
분기 = "2020/03(E) (IFRS연결)"
# 여기에 코드를 작성하세요
print(분기[:7])
# Out:
# 2020/03

# %% [markdown]
# ### 040 strip 메서드

# %% [markdown]
# 문자열 좌우의 공백을 제거해보세요.
# ```python
# data = "   삼성전자    "
# ```
# ```
# 실행 예:
# 삼성전자
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>strip()</code> 메서드는 문자열 양쪽의 공백을 제거합니다. <code>lstrip()</code>은 왼쪽, <code>rstrip()</code>은 오른쪽만 제거합니다.</br>
# <pre>
# data = "   삼성전자    "
# data1 = data.strip()
# print(data1)
# </pre>
# </details>

# %%
data = "   삼성전자    "
# 여기에 코드를 작성하세요
spacedel = data.strip();
print(spacedel)
# Out:
# 삼성전자
