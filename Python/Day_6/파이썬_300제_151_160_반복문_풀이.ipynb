# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 08. 파이썬 반복문 (151 ~ 160)

# %% [markdown]
# ### 151 for문 + 조건문 (음수 출력)

# %% [markdown]
# for문을 사용해서 리스트의 음수만 출력하라.
# ```python
# 리스트 = [3, -20, -3, 44]
# ```
# ```
# 실행 예:
# -20
# -3
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# for문 안에 if문을 사용해 조건이 참인 경우에만 출력합니다.</br>
# <pre>
# 리스트 = [3, -20, -3, 44]
# for 변수 in 리스트:
#     if 변수 < 0:
#         print(변수)
# </pre>
# </details>

# %%
리스트 = [3, -20, -3, 44]
# 여기에 코드를 작성하세요
for 변수 in 리스트:
    if 변수 < 0:
        print(변수)
# Out:
# -20
# -3

# %% [markdown]
# ### 152 for문 + 조건문 (3의 배수 출력)

# %% [markdown]
# for문을 사용해서 3의 배수만을 출력하라.
# ```python
# 리스트 = [3, 100, 23, 44]
# ```
# ```
# 실행 예:
# 3
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 3으로 나눈 나머지(%)가 0이면 3의 배수입니다.</br>
# <pre>
# 리스트 = [3, 100, 23, 44]
# for 변수 in 리스트:
#     if 변수 % 3 == 0:
#         print(변수)
# </pre>
# </details>

# %%
리스트 = [3, 100, 23, 44]
# 여기에 코드를 작성하세요
for 변수 in 리스트:
    if 변수 % 3 == 0:
        print(변수)
# Out:
# 3

# %% [markdown]
# ### 153 for문 + 복합 조건 (20 미만 3의 배수)

# %% [markdown]
# 리스트에서 20보다 작은 3의 배수를 출력하라.
# ```python
# 리스트 = [13, 21, 12, 14, 30, 18]
# ```
# ```
# 실행 예:
# 12
# 18
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# and 연산자로 두 조건을 동시에 비교합니다.</br>
# <pre>
# 리스트 = [13, 21, 12, 14, 30, 18]
# for 변수 in 리스트:
#     if (변수 < 20) and (변수 % 3 == 0):
#         print(변수)
# </pre>
# </details>

# %%
리스트 = [13, 21, 12, 14, 30, 18]
# 여기에 코드를 작성하세요
for 변수 in 리스트:
    if (변수 < 20) and (변수 % 3 == 0):
        print(변수)
# Out:
# 12
# 18

# %% [markdown]
# ### 154 for문 + 조건문 (세 글자 이상 출력)

# %% [markdown]
# 리스트에서 세 글자 이상의 문자를 화면에 출력하라.
# ```python
# 리스트 = ["I", "study", "python", "language", "!"]
# ```
# ```
# 실행 예:
# study
# python
# language
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# len() 함수로 문자열 길이를 구해 3 이상인 경우만 출력합니다.</br>
# <pre>
# 리스트 = ["I", "study", "python", "language", "!"]
# for 변수 in 리스트:
#     if len(변수) >= 3:
#         print(변수)
# </pre>
# </details>

# %%
리스트 = ["I", "study", "python", "language", "!"]
# 여기에 코드를 작성하세요
for 변수 in 리스트:
    if len(변수) >= 3:
        print(변수)
# Out:
# study
# python
# language

# %% [markdown]
# ### 155 for문 + 조건문 (대문자만 출력)

# %% [markdown]
# 리스트에서 대문자만 화면에 출력하라.
# ```python
# 리스트 = ["A", "b", "c", "D"]
# ```
# ```
# 실행 예:
# A
# D
# ```
# (참고) `isupper()` 메서드는 대문자 여부를 판별합니다.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# 리스트 = ["A", "b", "c", "D"]
# for 변수 in 리스트:
#     if 변수.isupper():
#         print(변수)
# </pre>
# </details>

# %%
리스트 = ["A", "b", "c", "D"]
# 여기에 코드를 작성하세요
for 변수 in 리스트:
    if 변수.isupper():
        print(변수)
# Out:
# A
# D

# %% [markdown]
# ### 156 for문 + 조건문 (소문자만 출력)

# %% [markdown]
# 리스트에서 소문자만 화면에 출력하라.
# ```python
# 리스트 = ["A", "b", "c", "D"]
# ```
# ```
# 실행 예:
# b
# c
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# isupper()가 False인 경우(소문자)만 출력합니다.</br>
# <pre>
# 리스트 = ["A", "b", "c", "D"]
# for 변수 in 리스트:
#     if not 변수.isupper():
#         print(변수)
# </pre>
# </details>

# %%
리스트 = ["A", "b", "c", "D"]
# 여기에 코드를 작성하세요
for 변수 in 리스트:
    if not 변수.isupper():
        print(변수)
# Out:
# b
# c

# %% [markdown]
# ### 157 for문 + 첫 글자 대문자 변환

# %% [markdown]
# 이름의 첫 글자를 대문자로 변경해서 출력하라.
# ```python
# 리스트 = ['dog', 'cat', 'parrot']
# ```
# ```
# 실행 예:
# Dog
# Cat
# Parrot
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 인덱싱으로 첫 글자를 대문자로 바꾼 뒤 나머지 문자열과 이어붙입니다.</br>
# <pre>
# 리스트 = ['dog', 'cat', 'parrot']
# for 변수 in 리스트:
#     print(변수[0].upper() + 변수[1:])
#
# # 또는 capitalize() 메서드 활용:
# for 변수 in 리스트:
#     print(변수.capitalize())
# </pre>
# </details>

# %%
리스트 = ['dog', 'cat', 'parrot']
# 여기에 코드를 작성하세요
for 변수 in 리스트:
    print(변수[0].upper() + 변수[1:])
# Out:
# Dog
# Cat
# Parrot

# %% [markdown]
# ### 158 for문 + split (확장자 제거)

# %% [markdown]
# 파일 이름이 저장된 리스트에서 확장자를 제거하고 파일 이름만 출력하라.
# ```python
# 리스트 = ['hello.py', 'ex01.py', 'intro.hwp']
# ```
# ```
# 실행 예:
# hello
# ex01
# intro
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# split('.')으로 파일명과 확장자를 분리하고, 인덱스 0(파일명)만 출력합니다.</br>
# <pre>
# 리스트 = ['hello.py', 'ex01.py', 'intro.hwp']
# for 변수 in 리스트:
#     split = 변수.split(".")
#     print(split[0])
# </pre>
# </details>

# %%
리스트 = ['hello.py', 'ex01.py', 'intro.hwp']
# 여기에 코드를 작성하세요
for 변수 in 리스트:
    split = 변수.split(".")
    print(split[0])
# Out:
# hello
# ex01
# intro

# %% [markdown]
# ### 159 for문 + split + 조건 (.h 파일 출력)

# %% [markdown]
# 파일 이름이 저장된 리스트에서 확장자가 .h인 파일 이름을 출력하라.
# ```python
# 리스트 = ['intra.h', 'intra.c', 'define.h', 'run.py']
# ```
# ```
# 실행 예:
# intra.h
# define.h
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# split('.')으로 확장자를 추출하고 'h'인 경우만 출력합니다.</br>
# <pre>
# 리스트 = ['intra.h', 'intra.c', 'define.h', 'run.py']
# for 변수 in 리스트:
#     split = 변수.split(".")
#     if split[1] == "h":
#         print(변수)
# </pre>
# </details>

# %%
리스트 = ['intra.h', 'intra.c', 'define.h', 'run.py']
# 여기에 코드를 작성하세요
for 변수 in 리스트:
    split = 변수.split(".")
    if split[1] == "h":
        print(변수)
# Out:
# intra.h
# define.h

# %% [markdown]
# ### 160 for문 + split + or 조건 (.h 또는 .c 파일)

# %% [markdown]
# 파일 이름이 저장된 리스트에서 확장자가 .h나 .c인 파일을 출력하라.
# ```python
# 리스트 = ['intra.h', 'intra.c', 'define.h', 'run.py']
# ```
# ```
# 실행 예:
# intra.h
# intra.c
# define.h
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# or 연산자로 두 개의 확장자를 동시에 검사합니다.</br>
# <pre>
# 리스트 = ['intra.h', 'intra.c', 'define.h', 'run.py']
# for 변수 in 리스트:
#     split = 변수.split(".")
#     if (split[1] == "h") or (split[1] == "c"):
#         print(변수)
#
# # endswith 활용:
# for 변수 in 리스트:
#     if 변수.endswith((".h", ".c")):
#         print(변수)
# </pre>
# </details>

# %%
리스트 = ['intra.h', 'intra.c', 'define.h', 'run.py']
# 여기에 코드를 작성하세요
for 변수 in 리스트:
    if 변수.endswith((".h", ".c")):
        print(변수)

for 변수 in 리스트:
    split = 변수.split(".")
    if (split[1] == "h") or (split[1] == "c"):
        print(변수)
# Out:
# intra.h
# intra.c
# define.h
# intra.h
# intra.c
# define.h
